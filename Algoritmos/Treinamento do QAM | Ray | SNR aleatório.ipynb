# %% [markdown]
# # Treinamento QAM Rayleigh

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf
import os

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2023-07-02 22:19:30.149760: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-02 22:19:31.214615: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ketson/ns-allinone-2.35/otcl-1.14:/home/ketson/ns-allinone-2.35/lib
# 2023-07-02 22:19:31.214662: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-07-02 22:19:31.365169: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-07-02 22:19:34.227117: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ketson/ns-allinone-2.35/otcl-1.14:/home/ketson/ns-allinone-2.35/lib
# 2023-07-02 22:19:34.227419: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/ketson/ns-allinone-2.35/otcl-1.14:/home/ketson/ns-allinone-2.35/lib
# 2023-07-02 22:19:34.227440: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 14
#      10 from sklearn.pipeline import Pipeline
#      12 from libs.commpy_mod import SISOFlatChannel
# ---> 14 from files_01_detection.const_mod import generate_symbols, Model
#      15 from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
#      17 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~/Documentos/Pesquisa IC/Communication/Algoritmos/files_01_detection/const_mod.py:2
#       1 import numpy as np
# ----> 2 import commpy.modulation as cm
#       3 import commpy.utilities as cu
#       4 import matplotlib.pyplot as plt
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/commpy/__init__.py:21
#      19 from commpy.impairments import *
#      20 from commpy.sequences import *
# ---> 21 from commpy.channels import *
#      23 try:
#      24     from numpy.testing import Tester
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/commpy/channels.py:22
#       4 """
#       5 ============================================
#       6 Channel Models (:mod:`commpy.channels`)
#    (...)
#      17
#      18 """
#      20 from __future__ import division, print_function  # Python 2 compatibility
# ---> 22 from numpy import complex, abs, sqrt, sum, zeros, identity, hstack, einsum, trace, kron, absolute, fromiter, array, exp, \
#      23     pi, cos
#      24 from numpy.random import randn, random, standard_normal
#      25 from scipy.linalg import sqrtm
#
# ImportError: cannot import name 'complex' from 'numpy' (/home/ketson/.local/lib/python3.10/site-packages/numpy/__init__.py)

# %%
total_num_symbols  = 100000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.4 # Fraction of whole data to be used for training (the remaining is for testing)
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy
Mod = 'QAM'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = [16, 4]      # QAM modulation

# %%
def error(amostras, model, mod, M, channel_type, Es, code_rate, snr):
    frac = 10000
    if os.path.exists(f'bit_error/{channel_type}/rede-{model[1]}-{M}-{mod}-{snr[0]}-SNR.dat'):
        error = np.fromfile(f'bit_error/{channel_type}/rede-{model[1]}-{M}-{mod}-{snr[0]}-SNR.dat', dtype=np.float64)
    else:    
        error = 0
        a = amostras
        for i in range(amostras // frac + 1):
            if a < frac:
                frac = amostras % frac
            sub_amostras =  conjunto(Mod, frac, M, channel_type, Es, code_rate, snr, False)
            error += ser(model[0], tf.reshape(tf.convert_to_tensor(sub_amostras[0]), [-1, 3]),
                              tf.reshape(tf.convert_to_tensor(sub_amostras[1]), [-1, 1]), nn=True)
            a -= frac
        error /= amostras / frac
        error.tofile(f'bit_error/{channel_type}/rede-{model[1]}-{M}-{mod}-{snr[0]}-SNR.dat')
    return error

def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):

    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, [SNR_dB[0]])
    x = np.stack([np.real(channel_output[0][:]),
                    np.imag(channel_output[0][:])], axis=1)

    if scaler is not None:
        x = scaler(np.concatenate((x, np.array([channel_output[1]]).T), axis=1))
    else:
        x = np.concatenate((x, np.array([channel_output[1]]).T), axis=1)
    
    x = x.reshape(1,-1,3)
    
    for i in range(1, len(SNR_dB)):
        a, b, c = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB[i])
        
        d = np.stack([np.real(c[0][:]), np.imag(c[0][:])], axis=1)
        
        if scaler is not None:
            d = scaler(np.concatenate((d, np.array([c[1]]).T), axis=1))
        else:
            d = np.concatenate((d, np.array([c[1]]).T), axis=1)
        
        symbs = np.vstack((symbs, a))
        indices = np.vstack((indices, b))
        channel_output = np.vstack((channel_output, c))
        x = np.vstack((x, d.reshape(1,-1,3)))
    
    y = np.float_(indices)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
x_out = []
y_out = []
symbs = []

# %%
x_out.append(np.fromfile('Random_Data/SNR_10-20/Rayleigh/16-QAM/x_rand.dat', dtype=np.dtype('float64')).reshape((-1,3)))
y_out.append(np.fromfile('Random_Data/SNR_10-20/Rayleigh/16-QAM/y_rand.dat', dtype=np.dtype('float64')))
symbs.append(np.fromfile('Random_Data/SNR_10-20/Rayleigh/16-QAM/symb.dat', dtype=np.dtype('complex128')).reshape((1,-1)))

# %%
x_out.append(np.fromfile('Random_Data/SNR_5-12/Rayleigh/4-QAM/x_rand.dat', dtype=np.dtype('float64')).reshape((-1,3)))
y_out.append(np.fromfile('Random_Data/SNR_5-12/Rayleigh/4-QAM/y_rand.dat', dtype=np.dtype('float64')))
symbs.append(np.fromfile('Random_Data/SNR_5-12/Rayleigh/4-QAM/symb.dat', dtype=np.dtype('complex128')).reshape((1,-1)))

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
X_train = []
y_train = []
X_test = []
y_test = []
for i in range(len(M)):
    y_train.append(y_out[i][:train_size])
    X_train.append(x_out[i][:train_size])

    # Test
    y_test.append(y_out[i][train_size:])
    X_test.append(x_out[i][train_size:])

    #scaler = StandardScaler()
    #scaler.fit(X_train[i])  # Don't cheat - fit only on training data
    #X_train[i] = scaler.transform(X_train[i])
    #X_test[i] = scaler.transform(X_test[i])

# %%
for i in range(len(M)):
    plot_symbols(X_train[i], y_train[i], M[i], symbs[i])

# %%
n_inputs = 3

# %%
n_redes = 3
n_hidden = [[150, 80, 50],
            [300, 180, 90, 40],
            [500, 380, 240, 135, 80]]

n_outputs = M
learning_rate = [0.01, 0.01, 0.01]
n_epochs = [50, 50, 50]
batch_size = [8000, 16000, 24000]
momentum = [0.7, 0.8, 0.9]

# %%
y_train_tf = tf.reshape(tf.convert_to_tensor(y_train), [len(M), -1, 1])
y_test_tf = tf.reshape(tf.convert_to_tensor(y_test), [len(M), -1, 1])
X_test_tf = tf.convert_to_tensor(X_test)
X_train_tf = tf.convert_to_tensor(X_train)
# Out:
# 2023-06-12 16:33:20.347685: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.347788: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.347865: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.347940: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.348013: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.348089: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.348162: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.348235: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-06-12 16:33:20.348247: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Usando API Keras

# %%
from keras.models import model_from_json

model_QAM = []
for i in range(len(M)):
    for j in range(n_redes):
        with open(f"Modelos/rayleigh/model-{M[i]}-Rede-{j}.json", 'r') as json_file:
            loaded_model_json = json_file.read()

        # Cria o modelo a partir do arquivo JSON
        model = model_from_json(loaded_model_json)

        # Carrega os pesos do modelo a partir do arquivo h5
        model.load_weights(f"Modelos/rayleigh/model-{M[i]}-Rede-{j}.h5")
        
        model_QAM.append(model)

model_QAM = np.array(model_QAM).reshape(len(M), -1)
# Out:
# 2023-06-27 14:26:05.724319: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724428: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724506: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724581: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724655: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724731: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724802: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724876: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-06-27 14:26:05.724888: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model_QAM
# Out:
# array([[<keras.engine.functional.Functional object at 0x7f48e9123070>,
#         <keras.engine.functional.Functional object at 0x7f48e9122710>,
#         <keras.engine.functional.Functional object at 0x7f4951a24130>],
#        [<keras.engine.functional.Functional object at 0x7f48e911ef50>,
#         <keras.engine.functional.Functional object at 0x7f48e911f6a0>,
#         <keras.engine.functional.Functional object at 0x7f4951a260b0>]],
#       dtype=object)

# %%
inputs = tf.keras.Input(shape=(n_inputs,))
output = []

for k in range(len(M)):
    for i in range(n_redes):
        x = inputs
        for j in range(len(n_hidden[i])):
            x = tf.keras.layers.Dense(n_hidden[i][j], activation="elu", kernel_initializer="glorot_normal")(x)
        output.append(tf.keras.layers.Dense(n_outputs[k], kernel_initializer="glorot_normal")(x))
        del x

# %%
model_QAM = []
for k in range(len(M)):
    for i in range(n_redes):
        model_QAM.append(tf.keras.Model(inputs=inputs, outputs=output[i + 3*k]))

        model_QAM[i + 3*k].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                     optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate[i], momentum=momentum[i], nesterov=True),
                     metrics=["accuracy"])

        history = model_QAM[i + 3*k].fit(X_train_tf[k], y_train_tf[k], batch_size=batch_size[i], epochs=n_epochs[i], shuffle=True)

        tests_score = model_QAM[i + 3*k].evaluate(X_test_tf[k], y_test_tf[k])
        print("\nTest loss:", tests_score[0])
        print("Test accuracy:", tests_score[1])
        print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}\n")

model_QAM = np.array(model_QAM).reshape(len(M), -1)
# Out:
# Epoch 1/50
# 5/5 [==============================] -
# 3/3 [==============================] - 0s 83ms/step - loss: 1.0429 - accuracy: 0.7803
# Epoch 42/50
# 3/3 [==============================] - 0s 83ms/step - loss: 1.0202 - accuracy: 0.7821
# Epoch 43/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.9986 - accuracy: 0.7840
# Epoch 44/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.9779 - accuracy: 0.7857
# Epoch 45/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.9583 - accuracy: 0.7875
# Epoch 46/50
# 3/3 [==============================] - 0s 87ms/step - loss: 0.9396 - accuracy: 0.7897
# Epoch 47/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.9218 - accuracy: 0.7909
# Epoch 48/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.9050 - accuracy: 0.7917
# Epoch 49/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.8891 - accuracy: 0.7929
# Epoch 50/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.8740 - accuracy: 0.7933
# 30000/30000 [==============================] - 47s 2ms/step - loss: 0.8688 - accuracy: 0.7917
#
# Test loss: 0.8687897324562073
# Test accuracy: 0.7916562557220459
# Taxa de erro simbólica de 20.83%
#
# Epoch 1/50
# 2/2 [==============================] - 2s 338ms/step - loss: 2.8115 - accuracy: 9.7500e-04
# Epoch 2/50
# 2/2 [==============================] - 1s 339ms/step - loss: 2.7780 - accuracy: 0.0280
# Epoch 3/50
# 2/2 [==============================] - 1s 331ms/step - loss: 2.7294 - accuracy: 0.1259
# Epoch 4/50
# 2/2 [==============================] - 1s 350ms/step - loss: 2.6714 - accuracy: 0.1484
# Epoch 5/50
# 2/2 [==============================] - 1s 355ms/step - loss: 2.6085 - accuracy: 0.1978
# Epoch 6/50
# 2/2 [==============================] - 1s 352ms/step - loss: 2.5428 - accuracy: 0.2291
# Epoch 7/50
# 2/2 [==============================] - 1s 337ms/step - loss: 2.4755 - accuracy: 0.2466
# Epoch 8/50
# 2/2 [==============================] - 1s 342ms/step - loss: 2.4064 - accuracy: 0.2641
# Epoch 9/50
# 2/2 [==============================] - 1s 339ms/step - loss: 2.3349 - accuracy: 0.2811
# Epoch 10/50
# 2/2 [==============================] - 1s 350ms/step - loss: 2.2612 - accuracy: 0.3019
# Epoch 11/50
# 2/2 [==============================] - 1s 332ms/step - loss: 2.1847 - accuracy: 0.3248
# Epoch 12/50
# 2/2 [==============================] - 1s 333ms/step - loss: 2.1063 - accuracy: 0.3530
# Epoch 13/50
# 2/2 [==============================] - 1s 341ms/step - loss: 2.0267 - accuracy: 0.3913
# Epoch 14/50
# 2/2 [==============================] - 1s 350ms/step - loss: 1.9471 - accuracy: 0.4228
# Epoch 15/50
# 2/2 [==============================] - 1s 353ms/step - loss: 1.8686 - accuracy: 0.4381
# Epoch 16/50
# 2/2 [==============================] - 1s 350ms/step - loss: 1.7921 - accuracy: 0.4536
# Epoch 17/50
# 2/2 [==============================] - 1s 351ms/step - loss: 1.7186 - accuracy: 0.4706
# Epoch 18/50
# 2/2 [==============================] - 1s 353ms/step - loss: 1.6485 - accuracy: 0.4921
# Epoch 19/50
# 2/2 [==============================] - 1s 344ms/step - loss: 1.5819 - accuracy: 0.5213
# Epoch 20/50
# 2/2 [==============================] - 1s 354ms/step - loss: 1.5188 - accuracy: 0.5595
# Epoch 21/50
# 2/2 [==============================] - 1s 356ms/step - loss: 1.4590 - accuracy: 0.6009
# Epoch 22/50
# 2/2 [==============================] - 1s 351ms/step - loss: 1.4024 - accuracy: 0.6282
# Epoch 23/50
# 2/2 [==============================] - 1s 366ms/step - loss: 1.3489 - accuracy: 0.6468
# Epoch 24/50
# 2/2 [==============================] - 1s 384ms/step - loss: 1.2981 - accuracy: 0.6623
# Epoch 25/50
# 2/2 [==============================] - 1s 370ms/step - loss: 1.2498 - accuracy: 0.6809
# Epoch 26/50
# 2/2 [==============================] - 1s 351ms/step - loss: 1.2042 - accuracy: 0.6974
# Epoch 27/50
# 2/2 [==============================] - 1s 369ms/step - loss: 1.1613 - accuracy: 0.7129
# Epoch 28/50
# 2/2 [==============================] - 1s 348ms/step - loss: 1.1212 - accuracy: 0.7245
# Epoch 29/50
# 2/2 [==============================] - 1s 341ms/step - loss: 1.0834 - accuracy: 0.7371
# Epoch 30/50
# 2/2 [==============================] - 1s 348ms/step - loss: 1.0477 - accuracy: 0.7476
# Epoch 31/50
# 2/2 [==============================] - 1s 350ms/step - loss: 1.0141 - accuracy: 0.7563
# Epoch 32/50
# 2/2 [==============================] - 1s 355ms/step - loss: 0.9824 - accuracy: 0.7635
# Epoch 33/50
# 2/2 [==============================] - 1s 340ms/step - loss: 0.9527 - accuracy: 0.7691
# Epoch 34/50
# 2/2 [==============================] - 1s 345ms/step - loss: 0.9250 - accuracy: 0.7734
# Epoch 35/50
# 2/2 [==============================] - 1s 343ms/step - loss: 0.8991 - accuracy: 0.7777
# Epoch 36/50
# 2/2 [==============================] - 1s 337ms/step - loss: 0.8752 - accuracy: 0.7806
# Epoch 37/50
# 2/2 [==============================] - 1s 343ms/step - loss: 0.8531 - accuracy: 0.7830
# Epoch 38/50
# 2/2 [==============================] - 1s 348ms/step - loss: 0.8328 - accuracy: 0.7850
# Epoch 39/50
# 2/2 [==============================] - 1s 345ms/step - loss: 0.8142 - accuracy: 0.7871
# Epoch 40/50
# 2/2 [==============================] - 1s 346ms/step - loss: 0.7972 - accuracy: 0.7886
# Epoch 41/50
# 2/2 [==============================] - 1s 335ms/step - loss: 0.7817 - accuracy: 0.7903
# Epoch 42/50
# 2/2 [==============================] - 1s 339ms/step - loss: 0.7676 - accuracy: 0.7915
# Epoch 43/50
# 2/2 [==============================] - 1s 339ms/step - loss: 0.7549 - accuracy: 0.7925
# Epoch 44/50
# 2/2 [==============================] - 1s 340ms/step - loss: 0.7432 - accuracy: 0.7936
# Epoch 45/50
# 2/2 [==============================] - 1s 339ms/step - loss: 0.7327 - accuracy: 0.7947
# Epoch 46/50
# 2/2 [==============================] - 1s 339ms/step - loss: 0.7231 - accuracy: 0.7954
# Epoch 47/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.7143 - accuracy: 0.7968
# Epoch 48/50
# 2/2 [==============================] - 1s 349ms/step - loss: 0.7063 - accuracy: 0.7977
# Epoch 49/50
# 2/2 [==============================] - 1s 341ms/step - loss: 0.6989 - accuracy: 0.7991
# Epoch 50/50
# 2/2 [==============================] - 1s 329ms/step - loss: 0.6922 - accuracy: 0.7999
# 30000/30000 [==============================] - 70s 2ms/step - loss: 0.6950 - accuracy: 0.7980
#
# Test loss: 0.6949964761734009
# Test accuracy: 0.7980499863624573
# Taxa de erro simbólica de 20.20%
#
# Epoch 1/50
# 5/5 [==============================] - 1s 20ms/step - loss: 1.3549 - accuracy: 0.3663
# Epoch 2/50
# 5/5 [==============================] - 0s 20ms/step - loss: 1.1346 - accuracy: 0.8501
# Epoch 3/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.9611 - accuracy: 0.8834
# Epoch 4/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.8333 - accuracy: 0.8859
# Epoch 5/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.7367 - accuracy: 0.8866
# Epoch 6/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6621 - accuracy: 0.8871
# Epoch 7/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.6034 - accuracy: 0.8871
# Epoch 8/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5566 - accuracy: 0.8872
# Epoch 9/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.5188 - accuracy: 0.8873
# Epoch 10/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.4882 - accuracy: 0.8872
# Epoch 11/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4630 - accuracy: 0.8872
# Epoch 12/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4423 - accuracy: 0.8874
# Epoch 13/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4250 - accuracy: 0.8874
# Epoch 14/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.4106 - accuracy: 0.8873
# Epoch 15/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3984 - accuracy: 0.8872
# Epoch 16/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3880 - accuracy: 0.8872
# Epoch 17/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3792 - accuracy: 0.8872
# Epoch 18/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.3717 - accuracy: 0.8870
# Epoch 19/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3652 - accuracy: 0.8872
# Epoch 20/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3595 - accuracy: 0.8873
# Epoch 21/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3546 - accuracy: 0.8872
# Epoch 22/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3503 - accuracy: 0.8871
# Epoch 23/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3465 - accuracy: 0.8873
# Epoch 24/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3432 - accuracy: 0.8872
# Epoch 25/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3403 - accuracy: 0.8872
# Epoch 26/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3377 - accuracy: 0.8871
# Epoch 27/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.3355 - accuracy: 0.8871
# Epoch 28/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.3334 - accuracy: 0.8871
# Epoch 29/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3316 - accuracy: 0.8871
# Epoch 30/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3300 - accuracy: 0.8870
# Epoch 31/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3285 - accuracy: 0.8871
# Epoch 32/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3272 - accuracy: 0.8870
# Epoch 33/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3261 - accuracy: 0.8871
# Epoch 34/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3250 - accuracy: 0.8870
# Epoch 35/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3241 - accuracy: 0.8870
# Epoch 36/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3232 - accuracy: 0.8870
# Epoch 37/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3224 - accuracy: 0.8870
# Epoch 38/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.3217 - accuracy: 0.8871
# Epoch 39/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.3211 - accuracy: 0.8871
# Epoch 40/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3205 - accuracy: 0.8871
# Epoch 41/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3200 - accuracy: 0.8871
# Epoch 42/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3195 - accuracy: 0.8870
# Epoch 43/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3191 - accuracy: 0.8870
# Epoch 44/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3187 - accuracy: 0.8870
# Epoch 45/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3183 - accuracy: 0.8870
# Epoch 46/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.3180 - accuracy: 0.8868
# Epoch 47/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.3177 - accuracy: 0.8870
# Epoch 48/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.3174 - accuracy: 0.8868
# Epoch 49/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.3172 - accuracy: 0.8868
# Epoch 50/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3169 - accuracy: 0.8869
# 30000/30000 [==============================] - 39s 1ms/step - loss: 0.3166 - accuracy: 0.8887
#
# Test loss: 0.3165936768054962
# Test accuracy: 0.888658344745636
# Taxa de erro simbólica de 11.13%
#
# Epoch 1/50
# 3/3 [==============================] - 1s 82ms/step - loss: 1.3302 - accuracy: 0.4159
# Epoch 2/50
# 3/3 [==============================] - 0s 81ms/step - loss: 1.1520 - accuracy: 0.7827
# Epoch 3/50
# 3/3 [==============================] - 0s 94ms/step - loss: 0.9663 - accuracy: 0.8814
# Epoch 4/50
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8152 - accuracy: 0.8857
# Epoch 5/50
# 3/3 [==============================] - 0s 88ms/step - loss: 0.7005 - accuracy: 0.8869
# Epoch 6/50
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6143 - accuracy: 0.8868
# Epoch 7/50
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5495 - accuracy: 0.8873
# Epoch 8/50
# 3/3 [==============================] - 0s 99ms/step - loss: 0.5007 - accuracy: 0.8871
# Epoch 9/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.4636 - accuracy: 0.8870
# Epoch 10/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.4352 - accuracy: 0.8870
# Epoch 11/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.4133 - accuracy: 0.8871
# Epoch 12/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.3961 - accuracy: 0.8873
# Epoch 13/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.3826 - accuracy: 0.8874
# Epoch 14/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.3718 - accuracy: 0.8874
# Epoch 15/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.3631 - accuracy: 0.8874
# Epoch 16/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3560 - accuracy: 0.8874
# Epoch 17/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.3502 - accuracy: 0.8874
# Epoch 18/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.3454 - accuracy: 0.8874
# Epoch 19/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.3414 - accuracy: 0.8873
# Epoch 20/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.3380 - accuracy: 0.8872
# Epoch 21/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.3352 - accuracy: 0.8872
# Epoch 22/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.3328 - accuracy: 0.8873
# Epoch 23/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.3308 - accuracy: 0.8874
# Epoch 24/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.3290 - accuracy: 0.8876
# Epoch 25/50
# 3/3 [==============================] - 0s 92ms/step - loss: 0.3275 - accuracy: 0.8877
# Epoch 26/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.3263 - accuracy: 0.8877
# Epoch 27/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3251 - accuracy: 0.8877
# Epoch 28/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.3242 - accuracy: 0.8877
# Epoch 29/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.3233 - accuracy: 0.8877
# Epoch 30/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.3226 - accuracy: 0.8876
# Epoch 31/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.3220 - accuracy: 0.8876
# Epoch 32/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3214 - accuracy: 0.8877
# Epoch 33/50
# 3/3 [==============================] - 0s 87ms/step - loss: 0.3209 - accuracy: 0.8878
# Epoch 34/50
# 3/3 [==============================] - 0s 84ms/step - loss: 0.3205 - accuracy: 0.8877
# Epoch 35/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.3201 - accuracy: 0.8877
# Epoch 36/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.3198 - accuracy: 0.8877
# Epoch 37/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.3195 - accuracy: 0.8877
# Epoch 38/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.3192 - accuracy: 0.8877
# Epoch 39/50
# 3/3 [==============================] - 0s 86ms/step - loss: 0.3190 - accuracy: 0.8877
# Epoch 40/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.3188 - accuracy: 0.8875
# Epoch 41/50
# 3/3 [==============================] - 0s 102ms/step - loss: 0.3186 - accuracy: 0.8877
# Epoch 42/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.3184 - accuracy: 0.8876
# Epoch 43/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.3183 - accuracy: 0.8875
# Epoch 44/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3181 - accuracy: 0.8877
# Epoch 45/50
# 3/3 [==============================] - 0s 79ms/step - loss: 0.3180 - accuracy: 0.8877
# Epoch 46/50
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3179 - accuracy: 0.8876
# Epoch 47/50
# 3/3 [==============================] - 0s 83ms/step - loss: 0.3178 - accuracy: 0.8875
# Epoch 48/50
# 3/3 [==============================] - 0s 80ms/step - loss: 0.3177 - accuracy: 0.8876
# Epoch 49/50
# 3/3 [==============================] - 0s 81ms/step - loss: 0.3176 - accuracy: 0.8875
# Epoch 50/50
# 3/3 [==============================] - 0s 82ms/step - loss: 0.3175 - accuracy: 0.8875
# 30000/30000 [==============================] - 48s 2ms/step - loss: 0.3168 - accuracy: 0.8887
#
# Test loss: 0.3168271481990814
# Test accuracy: 0.8887010216712952
# Taxa de erro simbólica de 11.13%
#
# Epoch 1/50
# 2/2 [==============================] - 2s 337ms/step - loss: 1.3091 - accuracy: 0.5336
# Epoch 2/50
# 2/2 [==============================] - 1s 335ms/step - loss: 1.1964 - accuracy: 0.7879
# Epoch 3/50
# 2/2 [==============================] - 1s 349ms/step - loss: 1.0498 - accuracy: 0.8726
# Epoch 4/50
# 2/2 [==============================] - 1s 343ms/step - loss: 0.8974 - accuracy: 0.8827
# Epoch 5/50
# 2/2 [==============================] - 1s 335ms/step - loss: 0.7563 - accuracy: 0.8859
# Epoch 6/50
# 2/2 [==============================] - 1s 347ms/step - loss: 0.6359 - accuracy: 0.8870
# Epoch 7/50
# 2/2 [==============================] - 1s 344ms/step - loss: 0.5395 - accuracy: 0.8868
# Epoch 8/50
# 2/2 [==============================] - 1s 344ms/step - loss: 0.4664 - accuracy: 0.8870
# Epoch 9/50
# 2/2 [==============================] - 1s 340ms/step - loss: 0.4137 - accuracy: 0.8871
# Epoch 10/50
# 2/2 [==============================] - 1s 337ms/step - loss: 0.3770 - accuracy: 0.8873
# Epoch 11/50
# 2/2 [==============================] - 1s 346ms/step - loss: 0.3528 - accuracy: 0.8869
# Epoch 12/50
# 2/2 [==============================] - 1s 350ms/step - loss: 0.3372 - accuracy: 0.8870
# Epoch 13/50
# 2/2 [==============================] - 1s 374ms/step - loss: 0.3276 - accuracy: 0.8870
# Epoch 14/50
# 2/2 [==============================] - 1s 345ms/step - loss: 0.3220 - accuracy: 0.8868
# Epoch 15/50
# 2/2 [==============================] - 1s 349ms/step - loss: 0.3193 - accuracy: 0.8870
# Epoch 16/50
# 2/2 [==============================] - 1s 352ms/step - loss: 0.3180 - accuracy: 0.8871
# Epoch 17/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.3177 - accuracy: 0.8872
# Epoch 18/50
# 2/2 [==============================] - 1s 338ms/step - loss: 0.3179 - accuracy: 0.8872
# Epoch 19/50
# 2/2 [==============================] - 1s 346ms/step - loss: 0.3183 - accuracy: 0.8873
# Epoch 20/50
# 2/2 [==============================] - 1s 352ms/step - loss: 0.3187 - accuracy: 0.8873
# Epoch 21/50
# 2/2 [==============================] - 1s 340ms/step - loss: 0.3191 - accuracy: 0.8872
# Epoch 22/50
# 2/2 [==============================] - 1s 350ms/step - loss: 0.3193 - accuracy: 0.8873
# Epoch 23/50
# 2/2 [==============================] - 1s 341ms/step - loss: 0.3195 - accuracy: 0.8873
# Epoch 24/50
# 2/2 [==============================] - 1s 345ms/step - loss: 0.3195 - accuracy: 0.8873
# Epoch 25/50
# 2/2 [==============================] - 1s 336ms/step - loss: 0.3195 - accuracy: 0.8872
# Epoch 26/50
# 2/2 [==============================] - 1s 350ms/step - loss: 0.3193 - accuracy: 0.8872
# Epoch 27/50
# 2/2 [==============================] - 1s 357ms/step - loss: 0.3191 - accuracy: 0.8872
# Epoch 28/50
# 2/2 [==============================] - 1s 340ms/step - loss: 0.3188 - accuracy: 0.8872
# Epoch 29/50
# 2/2 [==============================] - 1s 349ms/step - loss: 0.3186 - accuracy: 0.8873
# Epoch 30/50
# 2/2 [==============================] - 1s 343ms/step - loss: 0.3183 - accuracy: 0.8873
# Epoch 31/50
# 2/2 [==============================] - 1s 351ms/step - loss: 0.3180 - accuracy: 0.8872
# Epoch 32/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.3177 - accuracy: 0.8872
# Epoch 33/50
# 2/2 [==============================] - 1s 339ms/step - loss: 0.3175 - accuracy: 0.8873
# Epoch 34/50
# 2/2 [==============================] - 1s 340ms/step - loss: 0.3172 - accuracy: 0.8873
# Epoch 35/50
# 2/2 [==============================] - 1s 344ms/step - loss: 0.3170 - accuracy: 0.8874
# Epoch 36/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.3169 - accuracy: 0.8873
# Epoch 37/50
# 2/2 [==============================] - 1s 348ms/step - loss: 0.3167 - accuracy: 0.8874
# Epoch 38/50
# 2/2 [==============================] - 1s 352ms/step - loss: 0.3166 - accuracy: 0.8874
# Epoch 39/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.3164 - accuracy: 0.8874
# Epoch 40/50
# 2/2 [==============================] - 1s 350ms/step - loss: 0.3163 - accuracy: 0.8874
# Epoch 41/50
# 2/2 [==============================] - 1s 332ms/step - loss: 0.3162 - accuracy: 0.8874
# Epoch 42/50
# 2/2 [==============================] - 1s 346ms/step - loss: 0.3161 - accuracy: 0.8874
# Epoch 43/50
# 2/2 [==============================] - 1s 347ms/step - loss: 0.3160 - accuracy: 0.8874
# Epoch 44/50
# 2/2 [==============================] - 1s 344ms/step - loss: 0.3160 - accuracy: 0.8874
# Epoch 45/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.3159 - accuracy: 0.8874
# Epoch 46/50
# 2/2 [==============================] - 1s 342ms/step - loss: 0.3158 - accuracy: 0.8874
# Epoch 47/50
# 2/2 [==============================] - 1s 338ms/step - loss: 0.3158 - accuracy: 0.8874
# Epoch 48/50
# 2/2 [==============================] - 1s 346ms/step - loss: 0.3157 - accuracy: 0.8873
# Epoch 49/50
# 2/2 [==============================] - 1s 349ms/step - loss: 0.3157 - accuracy: 0.8874
# Epoch 50/50
# 2/2 [==============================] - 1s 351ms/step - loss: 0.3156 - accuracy: 0.8873
# 30000/30000 [==============================] - 72s 2ms/step - loss: 0.3153 - accuracy: 0.8887
#
# Test loss: 0.3152635395526886
# Test accuracy: 0.8887437582015991
# Taxa de erro simbólica de 11.13%

# %%
for i in range(len(M)):
    for j in range(n_redes):
        model_json = model_QAM[i][j].to_json()
        with open(f"Modelos/rayleigh/model-{M[i]}-Rede-{j}.json", "w") as json_file:
            json_file.write(model_json)
        model_QAM[i][j].save_weights(f"Modelos/rayleigh/model-{M[i]}-Rede-{j}.h5")

# %%
for i in range(len(M)):
    print(f'Modelo {M[i]}-QAM:\n')
    for j in range(n_redes):
        plot_confusion_matrix(model_QAM[i][j], X_test_tf[i], y_test_tf[i], M[i], nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True, plot_training=False)
# Out:
# Modelo 16-QAM:
# Modelo 4-QAM:

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | Rayleigh

# %% [markdown]
# Obs: Subdividir amostras em conjuntos menores e realizar o treinamento (1000 subamostros por exemplo). Fazer a verificação de bits sem aproximação. Testar em um intervalo maior para verificar se a rede diverge em algum momento.

# %%
Mod = "QAM"
channel_type = "rayleigh"
init_scale = 1
interval = [90, 60]
passo = 8

# %%
Teo_SNRs = [[theoretical_error(Mod, M[k], init_scale + i, channel_type) for i in range(0, interval[k], passo)] for k in range(len(M))]

# %%
error_rate = [([[error(int(100 / (Teo_SNRs[k][int(i / passo)] * np.log2(M[k]))), [model_QAM[k][j], j], Mod, M[k], channel_type, Es, code_rate, [init_scale + i]) for i in range(0, interval[k], passo)] for j in range(n_redes)]) / (tf.math.log(float(M[k]))/tf.math.log(2.)) for k in range(len(M))]

# %%
error(int(100 / (Teo_SNRs[0][int(0 / passo)] * np.log2(M[0]))), [model_QAM[0][0], 0], Mod, M[0], channel_type, Es, code_rate, [init_scale + 0])
# Out:
# array([-7.4629786e-36,  1.8149999e+00], dtype=float32)

# %% [markdown]
# ### error_rate

# %%
np.fromfile(f'bit_error/awgn/rede-1-16-QAM-11-SNR.dat', dtype=np.float64)
# Out:
# array([0.18122977])

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 np.mean(error_rate - Teo_SNRs)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
import matplotlib.ticker as tick

for k in range(len(M)):
    y1 = Teo_SNRs[k]
    x = range(init_scale, init_scale + interval[k], passo)

    fig, ax = plt.subplots(1,1)

    ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
    [ax.plot(x, error_rate[k][i], 's--', label=f'Empirical Curve (Rede {i + 1})') for i in range(n_redes)]

    ax.set_title(f'{M[k]}-QAM - Rayleigh')
    ax.set_xlabel('SNR_dB')
    ax.set_ylabel('Taxa de erro por bit')

    def y_fmt(x, y):
        return '{:2.1e}'.format(x)

    ax.set_yscale("log")
    ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
    #plt.plot(x2, y2, 'rs--',  label='line 2')

    plt.legend()
    plt.show()
