# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow.compat.v1 as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_ser, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2022-12-06 20:01:33.328638: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-06 20:01:34.460696: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-06 20:01:34.460744: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-06 20:01:34.617518: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-06 20:01:37.012284: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-06 20:01:37.012474: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-06 20:01:37.012487: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'PSK'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 8      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.5 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = 15      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy

# %%
#plot theoretical symbol error probability (SER) for this SNR
Pe = theoretical_ser(Mod, M, SNR_dB, channel_type)
print("Theoretical symbol error probability (SER) =", 100.0*Pe, "% for SNR =", SNR_dB,"dB")
# Out:
# Theoretical symbol error probability (SER) = 44.75173852031923 % for SNR = 15 dB

# %%
symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = indices[:train_size]
X_train = np.stack([np.real(channel_output[:train_size]),
                    np.imag(channel_output[:train_size])], axis=1)

# Test
y_test = indices[train_size:]
X_test = np.stack([np.real(channel_output[train_size:]),
                   np.imag(channel_output[train_size:])], axis=1)

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]
n_hidden1 = 20
n_hidden2 = 10
n_outputs = M
learning_rate = 0.001
n_epochs = 100
batch_size = 5000

tf.compat.v1.disable_eager_execution()

X = tf.placeholder(tf.float32, shape=(None, n_inputs), name="X")
y = tf.placeholder(tf.int64, shape=(None), name="y")

# %%
#Função para a criação das camadas ocultas
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_inputs + n_neurons)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        
        W = tf.Variable(init, name="kernel")
        b = tf.Variable(tf.zeros([n_neurons]), name="bias")
        Z = tf.matmul(X, W) + b
        
        if activation is not None:
            return activation(Z)
        else:
            tf.print(Z)
            return Z

# %%
with tf.name_scope("dnn"):
    hidden1 = neuron_layer(X, n_hidden1, "hidden1", activation=tf.nn.relu)
    hidden2 = neuron_layer(hidden1, n_hidden1, "hidden2", activation=tf.nn.relu)
    logits = neuron_layer(hidden2, n_outputs, "outputs")

# %%
with tf.name_scope("loss"):
    tf.print(y)
    tf.print(logits)
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss = tf.reduce_mean(xentropy, name="loss")

# %%
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct = tf.nn.in_top_k(logits, y, 1)
    accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()

with tf.Session() as s:
    init.run()
    
    print(np.shape(logits.eval(feed_dict={X: X_train})))
    print(np.shape(y_train))
    print(y_train)
# Out:
# 2022-12-06 20:02:00.371997: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-12-06 20:02:00.372770: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-12-06 20:02:00.372822: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (keko-popos): /proc/driver/nvidia/version does not exist
# 2022-12-06 20:02:00.373921: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-06 20:02:00.406541: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2022-12-06 20:02:00.634567: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 40000000 exceeds 10% of free system memory.
# 2022-12-06 20:02:00.777183: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 40000000 exceeds 10% of free system memory.
# 2022-12-06 20:02:00.828016: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 16000000 exceeds 10% of free system memory.
# (500000, 8)
# (500000,)
# [3 1 7 ... 1 3 2]

# %%
init = tf.global_variables_initializer()

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for interation in range(np.shape(X_train)[0] // batch_size):
            X_batch = X_train[(interation*batch_size):(batch_size*(interation+1))]
            y_batch = y_train[(interation*batch_size):(batch_size*(interation+1))]
            sess.run(training_op, feed_dict={X: X_batch, y: y_batch})
        
        acc_train = accuracy.eval(feed_dict={X: X_batch, y: y_batch})
        acc_val = accuracy.eval(feed_dict={X: X_test, y: y_test})
        print(epoch, "Train accuracy:", acc_train, "Val accuracy:", acc_val)
    acc_val = accuracy.eval(feed_dict={X: X_test, y: y_test})
    print(acc_val)
    print(f'A taxa de erro simbólica obtida foi de {(1 - acc_val):.2%}')
# Out:
# 2022-12-06 20:02:07.702490: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 40000000 exceeds 10% of free system memory.
# 2022-12-06 20:02:07.727754: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 40000000 exceeds 10% of free system memory.
# 0 Train accuracy: 0.0274 Val accuracy: 0.029392
# 1 Train accuracy: 0.0934 Val accuracy: 0.103046
# 2 Train accuracy: 0.1644 Val accuracy: 0.173452
# 3 Train accuracy: 0.2374 Val accuracy: 0.237194
# 4 Train accuracy: 0.3402 Val accuracy: 0.343206
# 5 Train accuracy: 0.3608 Val accuracy: 0.367686
# 6 Train accuracy: 0.3834 Val accuracy: 0.3875
# 7 Train accuracy: 0.4036 Val accuracy: 0.410946
# 8 Train accuracy: 0.4316 Val accuracy: 0.437578
# 9 Train accuracy: 0.4592 Val accuracy: 0.46217
# 10 Train accuracy: 0.4794 Val accuracy: 0.481318
# 11 Train accuracy: 0.4996 Val accuracy: 0.501738
# 12 Train accuracy: 0.5396 Val accuracy: 0.542864
# 13 Train accuracy: 0.5848 Val accuracy: 0.583002
# 14 Train accuracy: 0.6178 Val accuracy: 0.61628
# 15 Train accuracy: 0.6388 Val accuracy: 0.640074
# 16 Train accuracy: 0.6536 Val accuracy: 0.654318
# 17 Train accuracy: 0.664 Val accuracy: 0.664084
# 18 Train accuracy: 0.6744 Val accuracy: 0.673426
# 19 Train accuracy: 0.6848 Val accuracy: 0.6871
# 20 Train accuracy: 0.6998 Val accuracy: 0.702342
# 21 Train accuracy: 0.7132 Val accuracy: 0.71386
# 22 Train accuracy: 0.7218 Val accuracy: 0.72467
# 23 Train accuracy: 0.7342 Val accuracy: 0.736792
# 24 Train accuracy: 0.7488 Val accuracy: 0.751956
# 25 Train accuracy: 0.7678 Val accuracy: 0.770518
# 26 Train accuracy: 0.7802 Val accuracy: 0.784458
# 27 Train accuracy: 0.7906 Val accuracy: 0.794596
# 28 Train accuracy: 0.8 Val accuracy: 0.804604
# 29 Train accuracy: 0.8098 Val accuracy: 0.814624
# 30 Train accuracy: 0.8228 Val accuracy: 0.823756
# 31 Train accuracy: 0.8318 Val accuracy: 0.832288
# 32 Train accuracy: 0.8404 Val accuracy: 0.839892
# 33 Train accuracy: 0.8488 Val accuracy: 0.846718
# 34 Train accuracy: 0.8544 Val accuracy: 0.852934
# 35 Train accuracy: 0.8606 Val accuracy: 0.858444
# 36 Train accuracy: 0.865 Val accuracy: 0.863428
# 37 Train accuracy: 0.8702 Val accuracy: 0.868018
# 38 Train accuracy: 0.8742 Val accuracy: 0.871838
# 39 Train accuracy: 0.876 Val accuracy: 0.875384
# 40 Train accuracy: 0.8784 Val accuracy: 0.878332
# 41 Train accuracy: 0.8808 Val accuracy: 0.8812
# 42 Train accuracy: 0.885 Val accuracy: 0.88363
# 43 Train accuracy: 0.888 Val accuracy: 0.885806
# 44 Train accuracy: 0.89 Val accuracy: 0.88785
# 45 Train accuracy: 0.8926 Val accuracy: 0.889602
# 46 Train accuracy: 0.8946 Val accuracy: 0.891274
