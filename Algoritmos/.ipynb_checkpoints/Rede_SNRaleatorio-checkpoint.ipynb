# %% [markdown]
# # Treinamento de Rede Neural com SNR aleatório

# %% [markdown]
# ## QAM Rayleigh

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2023-03-22 21:52:24.983418: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-22 21:52:25.951932: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-22 21:52:25.951957: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-22 21:52:26.063173: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-22 21:52:27.884275: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-22 21:52:27.884663: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-22 21:52:27.884683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.7 # Fraction of whole data to be used for training (the remaining is for testing)
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy
Mod = 'QAM'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 16      # PSK modulation

# %%
def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):

    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, [SNR_dB[0]])
    x = np.stack([np.real(channel_output[0][:]),
                    np.imag(channel_output[0][:])], axis=1)

    if scaler is not None:
        x = scaler(np.concatenate((x, np.array([channel_output[1]]).T), axis=1))
    else:
        x = np.concatenate((x, np.array([channel_output[1]]).T), axis=1)
    
    x = x.reshape(1,-1,3)
    
    for i in range(1, len(SNR_dB)):
        a, b, c = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB[i])
        
        d = np.stack([np.real(c[0][:]), np.imag(c[0][:])], axis=1)
        
        if scaler is not None:
            d = scaler(np.concatenate((d, np.array([c[1]]).T), axis=1))
        else:
            d = np.concatenate((d, np.array([c[1]]).T), axis=1)
        
        symbs = np.vstack((symbs, a))
        indices = np.vstack((indices, b))
        channel_output = np.vstack((channel_output, c))
        x = np.vstack((x, d.reshape(1,-1,3)))
    
    y = np.float_(indices)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
def Train_Data(Mod, total_num_symbols, M, channel_type, Es, code_rate, min, max):

    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, [min, max])
    x = np.stack([np.real(channel_output[0][:]),
                    np.imag(channel_output[0][:])], axis=1)
    x = np.concatenate((x, np.array([np.real(channel_output[1])]).T), axis=1)
    
    y = np.float_(indices[0])
    
    return x, y, symbs
"""
    indices = np.array([])
    symbs = np.array([])
    channel_output = np.array([])
    alpha = np.array([])
    for i in range(total_num_symbols):
        a, b, c = Model(Mod, 1, M, channel_type, Es, code_rate, np.random.randint(min, max))
        symbs = np.append(symbs, a)
        indices = np.append(indices, b)
        channel_output = np.append(channel_output, c[0])
        alpha = np.append(alpha, c[1])
        
    x = np.stack([np.real(channel_output[:]),
                        np.imag(channel_output[:])], axis=1)
    x = np.concatenate((x, np.array([alpha]).T), axis=1)
    
    y = np.float_(indices)
"""
# Out:
# '\n    indices = np.array([])\n    symbs = np.array([])\n    channel_output = np.array([])\n    alpha = np.array([])\n    for i in range(total_num_symbols):\n        a, b, c = Model(Mod, 1, M, channel_type, Es, code_rate, np.random.randint(min, max))\n        symbs = np.append(symbs, a)\n        indices = np.append(indices, b)\n        channel_output = np.append(channel_output, c[0])\n        alpha = np.append(alpha, c[1])\n        \n    x = np.stack([np.real(channel_output[:]),\n                        np.imag(channel_output[:])], axis=1)\n    x = np.concatenate((x, np.array([alpha]).T), axis=1)\n    \n    y = np.float_(indices)\n'

# %%
x_out, y_out, symbs = Train_Data(Mod, total_num_symbols, M, channel_type, Es, code_rate, 5, 30)

# %%
x_out = np.fromfile('Random_Data/SNR_8-12/Rayleigh/16-QAM/x_rand.dat', dtype=np.dtype('float64')).reshape((-1,3))
y_out = np.fromfile('Random_Data/SNR_8-12/Rayleigh/16-QAM/y_rand.dat', dtype=np.dtype('float64'))
symbs = np.fromfile('Random_Data/SNR_8-12/Rayleigh/16-QAM/symb.dat', dtype=np.dtype('complex128')).reshape((1,-1))

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:train_size]
X_train = x_out[:train_size]

# Test
y_test = y_out[train_size:]
X_test = x_out[train_size:]

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]

# %%
n_redes = 3
n_hidden = [[150, 80, 50],
            [300, 180, 90, 40],
            [500, 380, 240, 135, 80]]

n_outputs = M
learning_rate = [0.01, 0.01, 0.001]
n_epochs = [50, 50, 50]
batch_size = [8000, 16000, 24000]
momentum = [0.7, 0.8, 0.9]

# %%
y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(n_inputs,))
output = []

for i in range(n_redes):
    x = inputs
    for j in range(len(n_hidden[i])):
        x = tf.keras.layers.Dense(n_hidden[i][j], activation="elu", kernel_initializer="glorot_normal")(x)
    output.append(tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x))
    del x

# %%
model_QAM = []
for i in range(n_redes):
    model_QAM.append(tf.keras.Model(inputs=inputs, outputs=output[i]))

    model_QAM[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate[i], momentum=momentum[i], nesterov=True),
                 metrics=["accuracy"])

    history = model_QAM[i].fit(X_train, y_train, batch_size=batch_size[i], epochs=n_epochs[i], shuffle=True)

    tests_score = model_QAM[i].evaluate(X_test, y_test)
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}\n")
# Out:
# Epoch 1/50
# 88/88 [==============================] - 2s 21ms/step - loss: 2.3562 - accuracy: 0.2318
# Epoch 2/50
# 88/88 [==============================] - 2s 23ms/step - loss: 1.7380 - accuracy: 0.4379
# Epoch 3/50
# 88/88 [==============================] - 2s 22ms/step - loss: 1.4508 - accuracy: 0.5528
# Epoch 4/50
# 88/88 [==============================] - 2s 24ms/step - loss: 1.3062 - accuracy: 0.6016
# Epoch 5/50
# 88/88 [==============================] - 2s 24ms/step - loss: 1.2220 - accuracy: 0.6194
# Epoch 6/50
# 88/88 [==============================] - 2s 22ms/step - loss: 1.1731 - accuracy: 0.6262
# Epoch 7/50
# 88/88 [==============================] - 2s 23ms/step - loss: 1.1443 - accuracy: 0.6300
# Epoch 8/50
# 88/88 [==============================] - 2s 24ms/step - loss: 1.1257 - accuracy: 0.6322
# Epoch 9/50
# 88/88 [==============================] - 2s 25ms/step - loss: 1.1122 - accuracy: 0.6337
# Epoch 10/50
# 88/88 [==============================] - 2s 26ms/step - loss: 1.1013 - accuracy: 0.6346
# Epoch 11/50
# 88/88 [==============================] - 2s 23ms/step - loss: 1.0917 - accuracy: 0.6355
# Epoch 12/50
# 88/88 [==============================] - 2s 24ms/step - loss: 1.0829 - accuracy: 0.6360
# Epoch 13/50
# 88/88 [==============================] - 2s 26ms/step - loss: 1.0747 - accuracy: 0.6364
# Epoch 14/50
# 88/88 [==============================] - 2s 25ms/step - loss: 1.0670 - accuracy: 0.6366
# Epoch 15/50
# 88/88 [==============================] - 2s 25ms/step - loss: 1.0600 - accuracy: 0.6368
# Epoch 16/50
# 88/88 [==============================] - 2s 24ms/step - loss: 1.0537 - accuracy: 0.6369
# Epoch 17/50
# 88/88 [==============================] - 2s 24ms/step - loss: 1.0481 - accuracy: 0.6371
# Epoch 18/50
# 30/30 [==============================] - 19s 623ms/step - loss: 1.1248 - accuracy: 0.6308
# Epoch 37/50
# 30/30 [==============================] - 19s 633ms/step - loss: 1.1214 - accuracy: 0.6313
# Epoch 38/50
# 30/30 [==============================] - 19s 620ms/step - loss: 1.1182 - accuracy: 0.6317
# Epoch 39/50
# 30/30 [==============================] - 19s 616ms/step - loss: 1.1153 - accuracy: 0.6320
# Epoch 40/50
# 30/30 [==============================] - 19s 618ms/step - loss: 1.1124 - accuracy: 0.6322
# Epoch 41/50
# 30/30 [==============================] - 19s 631ms/step - loss: 1.1097 - accuracy: 0.6325
# Epoch 42/50
# 30/30 [==============================] - 19s 621ms/step - loss: 1.1071 - accuracy: 0.6328
# Epoch 43/50
# 30/30 [==============================] - 19s 627ms/step - loss: 1.1047 - accuracy: 0.6330
# Epoch 44/50
# 30/30 [==============================] - 19s 636ms/step - loss: 1.1023 - accuracy: 0.6333
# Epoch 45/50
# 30/30 [==============================] - 19s 617ms/step - loss: 1.0999 - accuracy: 0.6335
# Epoch 46/50
# 30/30 [==============================] - 18s 610ms/step - loss: 1.0977 - accuracy: 0.6337
# Epoch 47/50
# 30/30 [==============================] - 19s 630ms/step - loss: 1.0954 - accuracy: 0.6340
# Epoch 48/50
# 30/30 [==============================] - 19s 620ms/step - loss: 1.0933 - accuracy: 0.6342
# Epoch 49/50
# 30/30 [==============================] - 19s 622ms/step - loss: 1.0911 - accuracy: 0.6343
# Epoch 50/50
# 30/30 [==============================] - 19s 635ms/step - loss: 1.0890 - accuracy: 0.6344
# 9375/9375 [==============================] - 27s 3ms/step - loss: 1.0857 - accuracy: 0.6349
#
# Test loss: 1.0857340097427368
# Test accuracy: 0.6348833441734314
# Taxa de erro simbólica de 36.51%

# %%
for i in range(n_redes):
    plot_confusion_matrix(model_QAM[i], X_test, y_test, M, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | Rayleigh

# %%
Mod = "QAM"
channel_type = "rayleigh"
M = 16
init_scale = 2
interval = 18
passo = 1

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(200 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1, 3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(n_redes)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(3, 18), dtype=float32, numpy=
# array([[0.19194312, 0.16888888, 0.16286308, 0.13697319, 0.14298245,
#         0.12936509, 0.11434659, 0.09987437, 0.09230769, 0.08174905,
#         0.07125407, 0.06275862, 0.05005787, 0.04431599, 0.03560064,
#         0.03033268, 0.02260638, 0.021481  ],
#        [0.18957347, 0.1711111 , 0.16286308, 0.13218391, 0.14210527,
#         0.13015874, 0.11789773, 0.10238694, 0.09175824, 0.08460076,
#         0.07003257, 0.06241379, 0.05092593, 0.04527938, 0.03599841,
#         0.02723418, 0.0224734 , 0.0205095 ],
#        [0.18838863, 0.17      , 0.16390042, 0.13505746, 0.14210527,
#         0.12857144, 0.11434659, 0.10238694, 0.09395605, 0.08222433,
#         0.07247557, 0.06172414, 0.05208333, 0.0433526 , 0.03520286,
#         0.02723418, 0.02154255, 0.01932211]], dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# -0.021166965

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, error_rate[i], 's--', label=f'Empirical Curve (Rede {i + 1})') for i in range(n_redes)]

ax.set_title('16-QAM - Rayleigh')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ## QAM AWGN

# %%
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.7 # Fraction of whole data to be used for training (the remaining is for testing)
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy
Mod = 'QAM'
channel_type = 'awng' # 'awgn' or 'crazy'
M            = 16      # PSK modulation

# %%
x_out = np.fromfile('Random_Data/SNR_8-12/AWGN/16-QAM/x_rand.dat', dtype=np.dtype('float64')).reshape((-1,3))
y_out = np.fromfile('Random_Data/SNR_8-12/AWGN/16-QAM/y_rand.dat', dtype=np.dtype('float64'))
symbs = np.fromfile('Random_Data/SNR_8-12/AWGN/16-QAM/symb.dat', dtype=np.dtype('complex128')).reshape((1,-1))

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:train_size]
X_train = x_out[:train_size]

# Test
y_test = y_out[train_size:]
X_test = x_out[train_size:]

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]

# %%
n_redes = 3
n_hidden = [[150, 80, 50],
            [300, 180, 90, 40],
            [500, 380, 240, 135, 80]]

n_outputs = M
learning_rate = [0.01, 0.01, 0.001]
n_epochs = [50, 50, 50]
batch_size = [8000, 16000, 24000]
momentum = [0.7, 0.8, 0.9]

# %%
y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)
# Out:
# 2023-03-22 21:53:43.455165: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-03-22 21:53:43.458408: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-03-22 21:53:43.458486: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (keko-ubuntu): /proc/driver/nvidia/version does not exist
# 2023-03-22 21:53:43.464300: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(n_inputs,))
output = []

for i in range(n_redes):
    x = inputs
    for j in range(len(n_hidden[i])):
        x = tf.keras.layers.Dense(n_hidden[i][j], activation="elu", kernel_initializer="glorot_normal")(x)
    output.append(tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x))
    del x

# %%
model_QAM = []
for i in range(n_redes):
    model_QAM.append(tf.keras.Model(inputs=inputs, outputs=output[i]))
    
    model_QAM[i].summary()

    model_QAM[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate[i], momentum=momentum[i], nesterov=True),
                 metrics=["accuracy"])

    history = model_QAM[i].fit(X_train, y_train, batch_size=batch_size[i], epochs=n_epochs[i], shuffle=True)

    tests_score = model_QAM[i].evaluate(X_test, y_test)
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}\n")
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 150)               600
#
#  dense_1 (Dense)             (None, 80)                12080
#
#  dense_2 (Dense)             (None, 50)                4050
#
#  dense_3 (Dense)             (None, 16)                816
#
# =================================================================
# Total params: 17,546
# Trainable params: 17,546
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 88/88 [==============================] - 2s 20ms/step - loss: 0.7734 - accuracy: 0.7599
# Epoch 2/50
# 88/88 [==============================] - 2s 20ms/step - loss: 0.7056 - accuracy: 0.7648
# Epoch 3/50
# 88/88 [==============================] - 2s 18ms/step - loss: 0.6705 - accuracy: 0.7672
# Epoch 4/50
# 88/88 [==============================] - 2s 19ms/step - loss: 0.6514 - accuracy: 0.7688
# Epoch 5/50
# 88/88 [==============================] - 2s 20ms/step - loss: 0.6404 - accuracy: 0.7701
# Epoch 6/50
# 88/88 [==============================] - 2s 21ms/step - loss: 0.6338 - accuracy: 0.7710
# Epoch 7/50
# 88/88 [==============================] - 2s 20ms/step - loss: 0.6296 - accuracy: 0.7717
# Epoch 8/50
# 88/88 [==============================] - 2s 20ms/step - loss: 0.6269 - accuracy: 0.7721
# Epoch 9/50
# 88/88 [==============================] - 2s 19ms/step - loss: 0.6251 - accuracy: 0.7723
# Epoch 10/50
# 88/88 [==============================] - 2s 20ms/step - loss: 0.6238 - accuracy: 0.7725
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense_4 (Dense)             (None, 300)               1200
#
#  dense_5 (Dense)             (None, 180)               54180
#
#  dense_6 (Dense)             (None, 90)                16290
#
#  dense_7 (Dense)             (None, 40)                3640
#
#  dense_8 (Dense)             (None, 16)                656
#
# =================================================================
# Total params: 75,966
# Trainable params: 75,966
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 44/44 [==============================] - 6s 128ms/step - loss: 2.2941 - accuracy: 0.2600
# Epoch 2/50
# 44/44 [==============================] - 6s 135ms/step - loss: 1.5153 - accuracy: 0.5143
# Epoch 3/50
# 44/44 [==============================] - 6s 133ms/step - loss: 1.1132 - accuracy: 0.6686
# Epoch 4/50
# 44/44 [==============================] - 6s 131ms/step - loss: 0.8867 - accuracy: 0.7264
# Epoch 5/50
# 44/44 [==============================] - 6s 134ms/step - loss: 0.7524 - accuracy: 0.7548
# Epoch 6/50
# 44/44 [==============================] - 6s 142ms/step - loss: 0.6856 - accuracy: 0.7639
# Epoch 7/50
# 44/44 [==============================] - 6s 144ms/step - loss: 0.6554 - accuracy: 0.7674
# Epoch 8/50
# 44/44 [==============================] - 6s 133ms/step - loss: 0.6411 - accuracy: 0.7691
# Epoch 9/50
# 44/44 [==============================] - 6s 131ms/step - loss: 0.6336 - accuracy: 0.7703
# Epoch 10/50
# 44/44 [==============================] - 6s 134ms/step - loss: 0.6293 - accuracy: 0.7712
# Epoch 11/50
# 44/44 [==============================] - 6s 127ms/step - loss: 0.6267 - accuracy: 0.7718
# Epoch 12/50
# 44/44 [==============================] - 6s 134ms/step - loss: 0.6250 - accuracy: 0.7721
# Epoch 13/50
# 44/44 [==============================] - 5s 123ms/step - loss: 0.6239 - accuracy: 0.7725
# Epoch 14/50
# 44/44 [==============================] - 6s 131ms/step - loss: 0.6232 - accuracy: 0.7728
# Epoch 15/50
# 44/44 [==============================] - 6s 129ms/step - loss: 0.6226 - accuracy: 0.7729
# Epoch 16/50
# 44/44 [==============================] - 6s 132ms/step - loss: 0.6223 - accuracy: 0.7730
# Epoch 17/50
# 44/44 [==============================] - 6s 142ms/step - loss: 0.6220 - accuracy: 0.7729
# Epoch 18/50
# 44/44 [==============================] - 6s 133ms/step - loss: 0.6218 - accuracy: 0.7730
# Epoch 19/50
# 44/44 [==============================] - 6s 136ms/step - loss: 0.6216 - accuracy: 0.7730
# Epoch 20/50
# 44/44 [==============================] - 6s 131ms/step - loss: 0.6215 - accuracy: 0.7731
# Epoch 21/50
# 44/44 [==============================] - 6s 134ms/step - loss: 0.6213 - accuracy: 0.7731
# Epoch 22/50
# 44/44 [==============================] - 6s 133ms/step - loss: 0.6212 - accuracy: 0.7731
# Epoch 23/50
# 44/44 [==============================] - 6s 132ms/step - loss: 0.6212 - accuracy: 0.7732
# Epoch 24/50
# 44/44 [==============================] - 6s 133ms/step - loss: 0.6211 - accuracy: 0.7731
# Epoch 25/50
# 44/44 [==============================] - 6s 129ms/step - loss: 0.6210 - accuracy: 0.7730
# Epoch 26/50
# 44/44 [==============================] - 6s 136ms/step - loss: 0.6209 - accuracy: 0.7731
# Epoch 27/50
# 44/44 [==============================] - 6s 138ms/step - loss: 0.6209 - accuracy: 0.7731
# Epoch 28/50
# 44/44 [==============================] - 6s 135ms/step - loss: 0.6209 - accuracy: 0.7731
# Epoch 29/50
# 44/44 [==============================] - 6s 134ms/step - loss: 0.6208 - accuracy: 0.7731
# Epoch 30/50
# 44/44 [==============================] - 6s 131ms/step - loss: 0.6208 - accuracy: 0.7732
# Epoch 31/50
# 44/44 [==============================] - 6s 136ms/step - loss: 0.6207 - accuracy: 0.7730
# Epoch 32/50
# 44/44 [==============================] - 6s 129ms/step - loss: 0.6207 - accuracy: 0.7733
# Epoch 33/50
# 44/44 [==============================] - 6s 133ms/step - loss: 0.6207 - accuracy: 0.7731
# Epoch 34/50
# 44/44 [==============================] - 6s 133ms/step - loss: 0.6206 - accuracy: 0.7733
# Epoch 35/50
# 44/44 [==============================] - 6s 131ms/step - loss: 0.6206 - accuracy: 0.7732
# Epoch 36/50
# 44/44 [==============================] - 6s 137ms/step - loss: 0.6205 - accuracy: 0.7732
# Epoch 37/50
# 44/44 [==============================] - 6s 135ms/step - loss: 0.6205 - accuracy: 0.7732
# Epoch 38/50
# 44/44 [==============================] - 6s 140ms/step - loss: 0.6205 - accuracy: 0.7732
# Epoch 39/50
# 44/44 [==============================] - 6s 135ms/step - loss: 0.6205 - accuracy: 0.7732
# Epoch 40/50
# 44/44 [==============================] - 6s 137ms/step - loss: 0.6204 - accuracy: 0.7732
# Epoch 41/50
# 44/44 [==============================] - 6s 138ms/step - loss: 0.6204 - accuracy: 0.7732
# Epoch 42/50
# 44/44 [==============================] - 6s 130ms/step - loss: 0.6204 - accuracy: 0.7732
# Epoch 43/50
# 44/44 [==============================] - 6s 140ms/step - loss: 0.6204 - accuracy: 0.7732
# Epoch 44/50
# 44/44 [==============================] - 6s 142ms/step - loss: 0.6204 - accuracy: 0.7731
# Epoch 45/50
# 44/44 [==============================] - 6s 145ms/step - loss: 0.6203 - accuracy: 0.7731
# Epoch 46/50
# 44/44 [==============================] - 7s 150ms/step - loss: 0.6203 - accuracy: 0.7732
# Epoch 47/50
# 44/44 [==============================] - 6s 144ms/step - loss: 0.6203 - accuracy: 0.7733
# Epoch 48/50
# 44/44 [==============================] - 6s 137ms/step - loss: 0.6203 - accuracy: 0.7730
# Epoch 49/50
# 44/44 [==============================] - 6s 132ms/step - loss: 0.6203 - accuracy: 0.7733
# Epoch 50/50
# 44/44 [==============================] - 6s 131ms/step - loss: 0.6202 - accuracy: 0.7731
# 9375/9375 [==============================] - 19s 2ms/step - loss: 0.6236 - accuracy: 0.7726
#
# Test loss: 0.6236470937728882
# Test accuracy: 0.7726233601570129
# Taxa de erro simbólica de 22.74%
#
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense_9 (Dense)             (None, 500)               2000
#
#  dense_10 (Dense)            (None, 380)               190380
#
#  dense_11 (Dense)            (None, 240)               91440
#
#  dense_12 (Dense)            (None, 135)               32535
#
#  dense_13 (Dense)            (None, 80)                10880
#
#  dense_14 (Dense)            (None, 16)                1296
#
# =================================================================
# Total params: 328,531
# Trainable params: 328,531
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 30/30 [==============================] - 20s 640ms/step - loss: 2.6294 - accuracy: 0.1917
# Epoch 2/50
# 30/30 [==============================] - 19s 623ms/step - loss: 2.3262 - accuracy: 0.3322
# Epoch 3/50
# 30/30 [==============================] - 18s 616ms/step - loss: 2.0701 - accuracy: 0.3601
# Epoch 4/50
# 30/30 [==============================] - 18s 614ms/step - loss: 1.8529 - accuracy: 0.3933
# Epoch 5/50
# 30/30 [==============================] - 19s 620ms/step - loss: 1.6726 - accuracy: 0.4512
# Epoch 6/50
# 30/30 [==============================] - 19s 615ms/step - loss: 1.5279 - accuracy: 0.4964
# Epoch 7/50
# 30/30 [==============================] - 19s 622ms/step - loss: 1.4128 - accuracy: 0.5498
# Epoch 38/50
# 30/30 [==============================] - 24s 806ms/step - loss: 0.6393 - accuracy: 0.7695
# Epoch 39/50
# 30/30 [==============================] - 23s 774ms/step - loss: 0.6376 - accuracy: 0.7697
# Epoch 40/50
# 30/30 [==============================] - 24s 805ms/step - loss: 0.6360 - accuracy: 0.7701
# Epoch 41/50
# 30/30 [==============================] - 23s 782ms/step - loss: 0.6346 - accuracy: 0.7702
# Epoch 42/50
# 30/30 [==============================] - 24s 790ms/step - loss: 0.6333 - accuracy: 0.7704
# Epoch 43/50
# 30/30 [==============================] - 25s 823ms/step - loss: 0.6322 - accuracy: 0.7706
# Epoch 44/50
# 30/30 [==============================] - 24s 792ms/step - loss: 0.6312 - accuracy: 0.7708
# Epoch 45/50
# 30/30 [==============================] - 25s 821ms/step - loss: 0.6302 - accuracy: 0.7710
# Epoch 46/50
# 30/30 [==============================] - 24s 800ms/step - loss: 0.6294 - accuracy: 0.7711
# Epoch 47/50
# 30/30 [==============================] - 24s 794ms/step - loss: 0.6287 - accuracy: 0.7713
# Epoch 48/50
# 30/30 [==============================] - 25s 831ms/step - loss: 0.6280 - accuracy: 0.7715
# Epoch 49/50
# 30/30 [==============================] - 24s 809ms/step - loss: 0.6274 - accuracy: 0.7715
# Epoch 50/50
# 30/30 [==============================] - 25s 842ms/step - loss: 0.6268 - accuracy: 0.7716
# 9375/9375 [==============================] - 26s 3ms/step - loss: 0.6294 - accuracy: 0.7715
#
# Test loss: 0.6294339299201965
# Test accuracy: 0.7714700102806091
# Taxa de erro simbólica de 22.85%

# %%
for i in range(n_redes):
    plot_confusion_matrix(model_QAM[i], X_test, y_test, M, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True, plot_training=False)
# Out:
# 2023-03-22 22:23:04.254590: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 360000000 exceeds 10% of free system memory.
# 2023-03-22 22:23:04.347897: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 360000000 exceeds 10% of free system memory.
# 2023-03-22 22:23:04.429163: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 360000000 exceeds 10% of free system memory.
# 2023-03-22 22:23:06.444008: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 600000000 exceeds 10% of free system memory.
# 2023-03-22 22:23:06.600157: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 600000000 exceeds 10% of free system memory.

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | AWGN

# %%
Mod = "QAM"
channel_type = "awgn"
M = 16
init_scale = 2
interval = 16
passo = 1

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1, 3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(n_redes)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(3, 16), dtype=float32, numpy=
# array([[0.17567568, 0.15923567, 0.14201184, 0.12634408, 0.1045673 ,
#         0.0987395 , 0.08510638, 0.06968391, 0.05555556, 0.03600324,
#         0.02680525, 0.01754386, 0.00752508, 0.00457941, 0.00178801,
#         0.00053863],
#        [0.17398648, 0.16401275, 0.14201184, 0.12231183, 0.10576923,
#         0.0987395 , 0.08333334, 0.06752873, 0.05611111, 0.03600324,
#         0.02680525, 0.01737517, 0.00771089, 0.0043571 , 0.00189529,
#         0.00056759],
#        [0.1722973 , 0.16242038, 0.14349112, 0.125     , 0.10216346,
#         0.09978992, 0.08333334, 0.06968391, 0.05555556, 0.03762136,
#         0.02680525, 0.01737517, 0.00789669, 0.00480171, 0.00180589,
#         0.00063709]], dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# -0.002495486

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, error_rate[i], 's--', label=f'Empirical Curve (Rede {i + 1})') for i in range(n_redes)]

ax.set_title('16-QAM - AWGN')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()
