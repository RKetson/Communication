# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2023-03-02 09:08:10.057532: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-02 09:08:10.057557: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-02 09:08:10.086556: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-02 09:08:10.814192: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-02 09:08:10.814273: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-02 09:08:10.814283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'PSK'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 4      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.8 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = [15, 25, 35]      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy
faixa_snr = len(SNR_dB)

# %%
#plot theoretical symbol error probability (SER) for this SNR
for s in SNR_dB:
    Pe = theoretical_error(Mod, M, s, channel_type, epb=False)
    print("Theoretical symbol error probability (SER) =", Pe*100, "% for SNR =", s,"dB")
# Out:
# Theoretical symbol error probability (SER) = 0.3147356282085845 % for SNR = 25 dB
# Theoretical symbol error probability (SER) = 0.031607784503007164 % for SNR = 35 dB

# %%
def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):

    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, [SNR_dB[0]])
    x = np.stack([np.real(channel_output[0][:]),
                    np.imag(channel_output[0][:])], axis=1)

    if scaler is not None:
        x = scaler(np.concatenate((x, np.array([channel_output[1]]).T), axis=1))
    else:
        x = np.concatenate((x, np.array([channel_output[1]]).T), axis=1)
    
    x = x.reshape(1,-1,3)
    
    for i in range(1, len(SNR_dB)):
        a, b, c = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, [SNR_dB[i]])
        
        d = np.stack([np.real(c[0][:]), np.imag(c[0][:])], axis=1)
        
        if scaler is not None:
            d = scaler(np.concatenate((d, np.array([c[1]]).T), axis=1))
        else:
            d = np.concatenate((d, np.array([c[1]]).T), axis=1)
        
        symbs = np.vstack((symbs, a))
        indices = np.vstack((indices, b))
        channel_output = np.vstack((channel_output, c))
        x = np.vstack((x, d.reshape(1,-1,3)))
    
    y = np.float_(indices)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
x_out
# Out:
# array([[[-6.68096922e-01, -3.55874831e-03,  6.35249698e-01],
#         [ 9.65003784e-01, -1.02986787e-02,  9.62660515e-01],
#         [ 4.70728153e-02,  7.47289577e-01,  7.64030802e-01],
#         ...,
#         [ 8.25461045e-03, -9.04666013e-01,  9.29849915e-01],
#         [-7.25780523e-01,  2.50508638e-02,  6.80973695e-01],
#         [ 2.75448176e-02, -9.39397181e-01,  9.56606655e-01]],
#
#        [[ 5.32635150e-01,  8.93860370e-03,  5.17248647e-01],
#         [-6.05636608e-03,  1.46921268e+00,  1.47872625e+00],
#         [-2.13649211e-03, -1.59097344e-01,  1.67173878e-01],
#         ...,
#         [ 3.53581462e-01,  3.46983615e-02,  3.64583511e-01],
#         [-1.36942833e-03,  4.86389859e-01,  4.94970938e-01],
#         [ 9.01463614e-04, -5.69966425e-01,  5.67820773e-01]]])

# %%
y_out
# Out:
# array([[3., 1., 2., ..., 0., 3., 0.],
#        [1., 2., 0., ..., 1., 2., 0.]])

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:,:train_size]
X_train = x_out[:,:train_size,:]

# Test
y_test = y_out[:,train_size:]
X_test = x_out[:,train_size:,:]

scaler = StandardScaler()
for i in range(faixa_snr):
    scaler.fit(X_train[i])  # Don't cheat - fit only on training data
    X_train[i] = scaler.transform(X_train[i])
    X_test[i] = scaler.transform(X_test[i])

# %%
for x, y, s in zip(X_train, y_train, symbs):
    plot_symbols(x, y, M, s)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train[0])[1]
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.01
n_epochs = 10
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [faixa_snr, -1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [faixa_snr, -1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)


#output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

# %%
model_PSK = np.array([])
for i in range(faixa_snr):
    model_PSK = np.append(model_PSK, tf.keras.Model(inputs=inputs, outputs=tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x), name=f"SNR_{SNR_dB[i]}"))

    model_PSK[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                 metrics=["accuracy"])

    history = model_PSK[i].fit(X_train[i], y_train[i], batch_size=batch_size, epochs=n_epochs, shuffle=True)

    tests_score = model_PSK[i].evaluate(X_test[i], y_test[i])
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica para SNR = {SNR_dB[i]} de {(1 - tests_score[1]):.2%}\n")
# Out:
# Epoch 1/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0367 - accuracy: 0.9924
# Epoch 2/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0095 - accuracy: 0.9971
# Epoch 3/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0087 - accuracy: 0.9971
# Epoch 4/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0085 - accuracy: 0.9971
# Epoch 5/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0084 - accuracy: 0.9971
# Epoch 6/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9971
# Epoch 7/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9971
# Epoch 8/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9971
# Epoch 9/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9971
# Epoch 10/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9971
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.0083 - accuracy: 0.9971
#
# Test loss: 0.008268645964562893
# Test accuracy: 0.9970549941062927
# Taxa de erro simbólica para SNR = 25 de 0.29%
#
# Epoch 1/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0114 - accuracy: 0.9982
# Epoch 2/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0029 - accuracy: 0.9997
# Epoch 3/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0023 - accuracy: 0.9997
# Epoch 4/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0019 - accuracy: 0.9997
# Epoch 5/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 6/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0016 - accuracy: 0.9997
# Epoch 7/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0015 - accuracy: 0.9997
# Epoch 8/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0014 - accuracy: 0.9997
# Epoch 9/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0013 - accuracy: 0.9997
# Epoch 10/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0013 - accuracy: 0.9997
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.0012 - accuracy: 0.9997
#
# Test loss: 0.0012236816110089421
# Test accuracy: 0.9996600151062012
# Taxa de erro simbólica para SNR = 35 de 0.03%

# %%
for m, x, y in zip(model_PSK, X_test, y_test):
    plot_confusion_matrix(m, x, y, M, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### PSK | Rayleigh

# %%
Mod = "PSK"
channel_type = "rayleigh"
M = 4
init_scale = 2
interval = 50
passo = 4

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(200 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_PSK[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))
# Out:
# 2023-03-02 09:22:28.520129: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 12000179400 exceeds 10% of free system memory.
# 2023-03-02 09:22:29.876381: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 12000179400 exceeds 10% of free system memory.
# 2023-03-02 09:22:31.320695: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 12000179400 exceeds 10% of free system memory.
# 2023-03-02 09:22:34.252040: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 6400095680 exceeds 10% of free system memory.
# 2023-03-02 09:22:38.303359: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 6400095680 exceeds 10% of free system memory.

# %%
error_rate
# Out:
# <tf.Tensor: shape=(2, 13), dtype=float32, numpy=
# array([[1.5100671e-01, 9.0239413e-02, 4.9019609e-02, 2.1800414e-02,
#         9.5215980e-03, 3.4690753e-03, 1.4013839e-03, 6.3904462e-04,
#         3.8394437e-04, 2.1589050e-04, 1.7617819e-04, 1.5673581e-04,
#         1.4852278e-04],
#        [1.4261745e-01, 8.1952117e-02, 4.1394334e-02, 1.7383950e-02,
#         7.1218456e-03, 2.8127637e-03, 1.1261121e-03, 4.5931333e-04,
#         1.9794023e-04, 8.0018130e-05, 3.9273382e-05, 1.7080185e-05,
#         1.0899837e-05]], dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# -0.001786434

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title(f'{M}-PSK - Rayleigh')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### PSK | AWGN

# %%
Mod = 'PSK'
channel_type = 'awgn'
interval = 11
init_scale = 2
passo = 2

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_PSK[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(2, 6), dtype=float32, numpy=
# array([[0.117357  , 0.07747253, 0.04367607, 0.02167146, 0.00791006,
#         0.00274931],
#        [0.10749507, 0.06648352, 0.0300273 , 0.0080819 , 0.00151003,
#         0.00012726]], dtype=float32)>

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title(f'{M}-PSK - AWGN')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ## Modelo QAM

# %%
Mod = "QAM"
channel_type = "awgn"
M = 4

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:,:train_size]
X_train = x_out[:,:train_size,:]

# Test
y_test = y_out[:,train_size:]
X_test = x_out[:,train_size:,:]
"""
scaler = StandardScaler()
for i in range(faixa_snr):
    scaler.fit(X_train[i])  # Don't cheat - fit only on training data
    X_train[i] = scaler.transform(X_train[i])
    X_test[i] = scaler.transform(X_test[i])
"""
# Out:
# "\nscaler = StandardScaler()\nfor i in range(faixa_snr):\n    scaler.fit(X_train[i])  # Don't cheat - fit only on training data\n    X_train[i] = scaler.transform(X_train[i])\n    X_test[i] = scaler.transform(X_test[i])\n"

# %%
for x, y, s in zip(X_train, y_train, symbs):
    plot_symbols(x, y, M, s)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train[0])[1]
#n_hidden1 = 300
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.001
n_epochs = 10
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [faixa_snr, -1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [faixa_snr, -1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

#x = tf.keras.layers.Dense(n_hidden4, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

#output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

# %%
model_QAM = np.array([])
for i in range(faixa_snr):
    model_QAM = np.append(model_QAM, tf.keras.Model(inputs=inputs, outputs=tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)))

    model_QAM[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                 metrics=["accuracy"])

    history = model_QAM[i].fit(X_train[i], y_train[i], batch_size=batch_size, epochs=n_epochs, shuffle=True)

    tests_score = model_QAM[i].evaluate(X_test[i], y_test[i])
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica para SNR = {SNR_dB[i]} de {(1 - tests_score[1]):.2%}\n")
# Out:
# Epoch 1/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.1295 - accuracy: 0.9802
# Epoch 2/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 3/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 4/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 5/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 6/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 8.1122e-04 - accuracy: 1.0000
# Epoch 7/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.5791e-04 - accuracy: 1.0000
# Epoch 8/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 5.5067e-04 - accuracy: 1.0000
# Epoch 9/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 4.7178e-04 - accuracy: 1.0000
# Epoch 10/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 4.1151e-04 - accuracy: 1.0000
# 6250/6250 [==============================] - 7s 1ms/step - loss: 3.8617e-04 - accuracy: 1.0000
#
# Test loss: 0.0003861698496621102
# Test accuracy: 1.0
# Taxa de erro simbólica para SNR = 25 de 0.00%
#
# Epoch 1/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0436 - accuracy: 0.9901
# Epoch 2/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 3/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 4/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 8.6447e-04 - accuracy: 1.0000
# Epoch 5/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 6.4959e-04 - accuracy: 1.0000
# Epoch 6/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 5.1740e-04 - accuracy: 1.0000
# Epoch 7/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 4.2824e-04 - accuracy: 1.0000
# Epoch 8/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 3.6424e-04 - accuracy: 1.0000
# Epoch 9/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 3.1620e-04 - accuracy: 1.0000
# Epoch 10/10
# 1000/1000 [==============================] - 4s 4ms/step - loss: 2.7887e-04 - accuracy: 1.0000
# 6250/6250 [==============================] - 7s 1ms/step - loss: 2.6278e-04 - accuracy: 1.0000
#
# Test loss: 0.0002627765934448689
# Test accuracy: 1.0
# Taxa de erro simbólica para SNR = 35 de 0.00%

# %%
for m, x, y in zip(model_QAM, X_test, y_test):
    plot_confusion_matrix(m, x, y, M, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | Rayleigh

# %%
Mod = 'QAM'
channel_type = 'rayleigh'
M = 4
init_scale = 2
interval = 44
passo = 4

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(200 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(2, 11), dtype=float32, numpy=
# array([[0.15939598, 0.09576427, 0.03921569, 0.0192633 , 0.01079889,
#         0.00709441, 0.00595588, 0.00482029, 0.00468989, 0.00449607,
#         0.00451376],
#        [0.15855704, 0.09898711, 0.03812636, 0.01747792, 0.00897972,
#         0.00567241, 0.00436681, 0.00344235, 0.00333415, 0.0031825 ,
#         0.00317625]], dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# 0.0014321484

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title(f'{M}-QAM - Rayleigh')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### QAM | AWGN

# %%
Mod = 'QAM'
channel_type = 'awgn'
init_scale = 2
interval = 11
passo = 2

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
np.mean(error_rate[0] - Teo_SNRs)
# Out:
# 0.00279569

# %%
np.mean(error_rate[1] - Teo_SNRs)
# Out:
# 0.0010894615

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title(f'{M}-QAM - AWGN')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()
