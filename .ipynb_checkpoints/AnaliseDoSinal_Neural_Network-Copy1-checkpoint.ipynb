# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_ser, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2022-12-04 16:26:49.901533: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-04 16:26:50.073380: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-04 16:26:50.073401: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-04 16:26:50.106311: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-04 16:26:50.787012: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-04 16:26:50.787078: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-04 16:26:50.787086: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'QAM'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 16      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.5 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = 15      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy

# %%
#plot theoretical symbol error probability (SER) for this SNR
Pe = theoretical_ser(Mod, M, SNR_dB, channel_type, Es)
print("Theoretical symbol error probability (SER) =", 100.0*Pe, "% for SNR =", SNR_dB,"dB")
# Out:
# Theoretical symbol error probability (SER) = 69.82162742627268 % for SNR = 15 dB

# %%
symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = np.append(np.array([[]]), indices[:train_size])
X_train = np.stack([np.real(channel_output[:train_size]),
                    np.imag(channel_output[:train_size])], axis=1)

# Test
y_test = np.append(np.array([[]]), indices[train_size:])
X_test = np.stack([np.real(channel_output[train_size:]),
                   np.imag(channel_output[train_size:])], axis=1)

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]
n_hidden1 = 20
n_hidden2 = 10
n_outputs = M
learning_rate = 0.001
n_epochs = 100
batch_size = 5000

y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(2,))

x = tf.keras.layers.Dense(n_hidden1, activation="relu", kernel_initializer="glorot_normal")(inputs)
x = tf.keras.layers.Dense(n_hidden2, activation="relu", kernel_initializer="glorot_normal")(x)
output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)

modelK = tf.keras.Model(inputs=inputs, outputs=output)

modelK.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 2)]               0
#
#  dense_6 (Dense)             (None, 50)                150
#
#  dense_7 (Dense)             (None, 30)                1530
#
#  dense_8 (Dense)             (None, 16)                496
#
# =================================================================
# Total params: 2,176
# Trainable params: 2,176
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelK.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
             metrics=["accuracy"])

history = modelK.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, shuffle=True)

tests_score = modelK.evaluate(X_test, y_test)
print("Test loss:", tests_score[0])
print("Test accuracy:", tests_score[1])
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.8164 - accuracy: 0.0641
# Epoch 2/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.8060 - accuracy: 0.0658
# Epoch 3/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7962 - accuracy: 0.0672
# Epoch 4/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7867 - accuracy: 0.0693
# Epoch 5/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7775 - accuracy: 0.0723
# Epoch 6/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7685 - accuracy: 0.0771
# Epoch 7/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7597 - accuracy: 0.0828
# Epoch 8/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7510 - accuracy: 0.0875
# Epoch 9/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7423 - accuracy: 0.0909
# Epoch 10/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7337 - accuracy: 0.0935
# Epoch 11/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.7250 - accuracy: 0.0958
# Epoch 12/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7164 - accuracy: 0.0980
# Epoch 13/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.7079 - accuracy: 0.1006
# Epoch 14/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.6993 - accuracy: 0.1020
# Epoch 15/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.6908 - accuracy: 0.1027
# Epoch 16/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.6822 - accuracy: 0.1037
# Epoch 17/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.6737 - accuracy: 0.1046
# Epoch 18/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.6651 - accuracy: 0.1056
# Epoch 19/100
# 100/100 [==============================] - 1s 8ms/step - loss: 2.6566 - accuracy: 0.1061
# Epoch 20/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.6480 - accuracy: 0.1076
# Epoch 21/100
# 100/100 [==============================] - 1s 8ms/step - loss: 2.6395 - accuracy: 0.1106
# Epoch 22/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.6309 - accuracy: 0.1155
# Epoch 23/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.6224 - accuracy: 0.1225
# Epoch 24/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.6138 - accuracy: 0.1321
# Epoch 25/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.6052 - accuracy: 0.1421
# Epoch 26/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5965 - accuracy: 0.1507
# Epoch 27/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5878 - accuracy: 0.1566
# Epoch 28/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5791 - accuracy: 0.1613
# Epoch 29/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5704 - accuracy: 0.1658
# Epoch 30/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.5616 - accuracy: 0.1703
# Epoch 31/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5527 - accuracy: 0.1747
# Epoch 32/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5439 - accuracy: 0.1793
# Epoch 33/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5350 - accuracy: 0.1845
# Epoch 34/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5261 - accuracy: 0.1914
# Epoch 35/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5173 - accuracy: 0.2004
# Epoch 36/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.5083 - accuracy: 0.2102
# Epoch 37/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4994 - accuracy: 0.2183
# Epoch 38/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4903 - accuracy: 0.2228
# Epoch 39/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4811 - accuracy: 0.2260
# Epoch 40/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4719 - accuracy: 0.2288
# Epoch 41/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4625 - accuracy: 0.2319
# Epoch 42/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4530 - accuracy: 0.2359
# Epoch 43/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4434 - accuracy: 0.2413
# Epoch 44/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4337 - accuracy: 0.2474
# Epoch 45/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4239 - accuracy: 0.2523
# Epoch 46/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.4140 - accuracy: 0.2565
# Epoch 47/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.4040 - accuracy: 0.2601
# Epoch 48/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3939 - accuracy: 0.2633
# Epoch 49/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.3837 - accuracy: 0.2668
# Epoch 50/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.3734 - accuracy: 0.2704
# Epoch 51/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3630 - accuracy: 0.2745
# Epoch 52/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.3525 - accuracy: 0.2791
# Epoch 53/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.3420 - accuracy: 0.2837
# Epoch 54/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.3313 - accuracy: 0.2880
# Epoch 55/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.3205 - accuracy: 0.2926
# Epoch 56/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3096 - accuracy: 0.2977
# Epoch 57/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2986 - accuracy: 0.3038
# Epoch 58/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2875 - accuracy: 0.3104
# Epoch 59/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2763 - accuracy: 0.3173
# Epoch 60/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2650 - accuracy: 0.3239
# Epoch 61/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2536 - accuracy: 0.3300
# Epoch 62/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2421 - accuracy: 0.3349
# Epoch 63/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2304 - accuracy: 0.3386
# Epoch 64/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2187 - accuracy: 0.3417
# Epoch 65/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.2069 - accuracy: 0.3441
# Epoch 66/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.1949 - accuracy: 0.3463
# Epoch 67/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.1829 - accuracy: 0.3485
# Epoch 68/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.1708 - accuracy: 0.3504
# Epoch 69/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.1586 - accuracy: 0.3522
# Epoch 70/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.1464 - accuracy: 0.3537
# Epoch 71/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.1341 - accuracy: 0.3553
# Epoch 72/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.1217 - accuracy: 0.3566
# Epoch 73/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.1093 - accuracy: 0.3580
# Epoch 74/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.0969 - accuracy: 0.3602
# Epoch 75/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.0844 - accuracy: 0.3626
# Epoch 76/100
# 100/100 [==============================] - 1s 6ms/step - loss: 2.0719 - accuracy: 0.3654
# Epoch 77/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.0594 - accuracy: 0.3682
# Epoch 78/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.0468 - accuracy: 0.3714
# Epoch 79/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.0342 - accuracy: 0.3748
# Epoch 80/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.0216 - accuracy: 0.3780
# Epoch 81/100
# 100/100 [==============================] - 1s 7ms/step - loss: 2.0090 - accuracy: 0.3811
# Epoch 82/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9963 - accuracy: 0.3845
# Epoch 83/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9837 - accuracy: 0.3880
# Epoch 84/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9710 - accuracy: 0.3917
# Epoch 85/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9584 - accuracy: 0.3958
# Epoch 86/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9459 - accuracy: 0.4001
# Epoch 87/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9334 - accuracy: 0.4071
# Epoch 88/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9210 - accuracy: 0.4172
# Epoch 89/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.9086 - accuracy: 0.4291
# Epoch 90/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8964 - accuracy: 0.4417
# Epoch 91/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8842 - accuracy: 0.4531
# Epoch 92/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8722 - accuracy: 0.4621
# Epoch 93/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8603 - accuracy: 0.4699
# Epoch 94/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8484 - accuracy: 0.4763
# Epoch 95/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8367 - accuracy: 0.4825
# Epoch 96/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8252 - accuracy: 0.4880
# Epoch 97/100
# 100/100 [==============================] - 1s 6ms/step - loss: 1.8137 - accuracy: 0.4931
# Epoch 98/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.8024 - accuracy: 0.4977
# Epoch 99/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.7912 - accuracy: 0.5022
# Epoch 100/100
# 100/100 [==============================] - 1s 7ms/step - loss: 1.7801 - accuracy: 0.5059
# 15625/15625 [==============================] - 30s 2ms/step - loss: 1.7746 - accuracy: 0.5088
# Test loss: 1.7745798826217651
# Test accuracy: 0.5087680220603943

# %% [markdown]
# ### Modelo de Rede Neural Criado

# %%
y_test = tf.cast(tf.reshape(y_test, -1),tf.int32)
y_train = tf.cast(tf.reshape(y_train, -1),tf.int32)

# %%
class DenseLayer(tf.Module):
    def __init__(self, n_neurons, name=None):
        super().__init__(name=name)
        self.n_neurons = n_neurons
        self.is_built = False
        
    def __call__(self, X, activation=None, name=None):
        if not self.is_built:
            self.w = tf.Variable(tf.random.truncated_normal((X.shape[-1], self.n_neurons), stddev=(2 / tf.sqrt(tf.cast(self.n_neurons + X.shape[-1], tf.float32)))), name=str(name)+"W")
            self.b = tf.Variable(tf.zeros([self.n_neurons]), dtype=tf.float32, name=str(name)+"b")
            self.is_built = True
            
        Z = tf.matmul(X, self.w) + self.b
        if activation is None:
            return Z
        else:
            return activation(Z)

# %%
class SequencialModel(tf.Module):
    def __init__(self, n_hidden=None, name=None):
        super().__init__(name=name)
        
        self.hidden1 = DenseLayer(n_hidden1)
        self.hidden2 = DenseLayer(n_hidden2)
        self.output = DenseLayer(n_outputs)
    
    def __call__(self, X):
        x = self.hidden1(tf.cast(X, tf.float32), activation=tf.nn.relu, name="hidden1-")
        x = self.hidden2(x, activation=tf.nn.relu, name="hidden2-")
        
        return self.output(x, name="output-")

# %%
model = SequencialModel()

# %%
def loss(y, logits):
    return tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits))

# %%
def train(model, x, y, learning_rate):
    with tf.GradientTape() as g:
        current_loss = loss(y, tf.cast(model(x), tf.float32))
        
    dp = g.gradient(current_loss, model.trainable_variables)
    
    for i in range(len(model.trainable_variables)):
        model.trainable_variables[i].assign_sub(learning_rate * dp[i])

# %%
def minilote(model, x, y):
    for _ in range(n_epochs):
        for interation in range(x.shape[0] // batch_size):
            X_batch, y_batch = x[interation*batch_size:(interation+1)*batch_size], y[interation*batch_size:(interation+1)*batch_size]
            train(model, X_batch, y_batch, learning_rate)
        print(f"Época número {_}, precisão de {(1 - accuracy(model, x, y)):.2%}")

# %%
def accuracy(model, x, y):
    correct = tf.nn.in_top_k(y, model(x), 1)
    return tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
minilote(model, X_train, y_train)
# Out:
# 2022-12-04 16:30:00.072098: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 40000000 exceeds 10% of free system memory.
# 2022-12-04 16:30:00.077667: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 40000000 exceeds 10% of free system memory.
# 2022-12-04 16:30:00.085978: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 40000000 exceeds 10% of free system memory.
# 2022-12-04 16:30:00.100621: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 20000000 exceeds 10% of free system memory.
# 2022-12-04 16:30:00.109221: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 20000000 exceeds 10% of free system memory.
# Época número 0, precisão de 83.55%
# Época número 1, precisão de 82.34%
# Época número 2, precisão de 81.10%
# Época número 3, precisão de 79.40%
# Época número 4, precisão de 77.44%
# Época número 5, precisão de 75.12%
# Época número 6, precisão de 73.32%
# Época número 7, precisão de 72.13%
# Época número 8, precisão de 71.15%
# Época número 9, precisão de 70.30%
# Época número 10, precisão de 69.62%
# Época número 11, precisão de 69.04%
# Época número 12, precisão de 68.58%
# Época número 13, precisão de 68.04%
# Época número 14, precisão de 64.40%
# Época número 15, precisão de 62.07%
# Época número 16, precisão de 59.97%
# Época número 17, precisão de 55.30%
# Época número 18, precisão de 50.83%
# Época número 19, precisão de 48.56%
# Época número 20, precisão de 47.31%
# Época número 21, precisão de 46.48%
# Época número 22, precisão de 45.89%
# Época número 23, precisão de 45.41%
# Época número 24, precisão de 44.93%
# Época número 25, precisão de 44.42%
# Época número 26, precisão de 43.84%
# Época número 27, precisão de 43.21%
# Época número 28, precisão de 42.47%
# Época número 29, precisão de 41.62%
# Época número 30, precisão de 40.72%
# Época número 31, precisão de 39.86%
# Época número 32, precisão de 39.14%
# Época número 33, precisão de 38.71%
# Época número 34, precisão de 38.48%
# Época número 35, precisão de 38.32%
# Época número 36, precisão de 38.17%
# Época número 37, precisão de 38.02%
# Época número 38, precisão de 37.87%
# Época número 39, precisão de 37.74%
# Época número 40, precisão de 37.59%
# Época número 41, precisão de 37.47%
# Época número 42, precisão de 37.36%
# Época número 43, precisão de 37.27%
# Época número 44, precisão de 37.17%
# Época número 45, precisão de 37.08%
# Época número 46, precisão de 37.00%
# Época número 47, precisão de 36.91%
# Época número 48, precisão de 36.63%
# Época número 49, precisão de 36.14%
# Época número 50, precisão de 35.56%
# Época número 51, precisão de 34.98%
# Época número 52, precisão de 34.33%
# Época número 53, precisão de 33.60%
# Época número 54, precisão de 32.85%
# Época número 55, precisão de 32.11%
# Época número 56, precisão de 31.46%
# Época número 57, precisão de 30.89%
# Época número 58, precisão de 30.40%
# Época número 59, precisão de 30.04%
# Época número 60, precisão de 29.74%
# Época número 61, precisão de 29.50%
# Época número 62, precisão de 29.30%
# Época número 63, precisão de 29.14%
# Época número 64, precisão de 29.01%
# Época número 65, precisão de 28.89%
# Época número 66, precisão de 28.77%
# Época número 67, precisão de 28.67%
# Época número 68, precisão de 28.57%
# Época número 69, precisão de 28.47%
# Época número 70, precisão de 28.37%
# Época número 71, precisão de 28.27%
# Época número 72, precisão de 28.18%
# Época número 73, precisão de 28.10%
# Época número 74, precisão de 28.00%
# Época número 75, precisão de 27.92%
# Época número 76, precisão de 27.83%
# Época número 77, precisão de 27.74%
# Época número 78, precisão de 27.66%
# Época número 79, precisão de 27.58%
# Época número 80, precisão de 27.50%
# Época número 81, precisão de 27.43%
# Época número 82, precisão de 27.35%
# Época número 83, precisão de 27.28%
# Época número 84, precisão de 27.20%
# Época número 85, precisão de 27.14%
# Época número 86, precisão de 27.08%
# Época número 87, precisão de 27.01%
# Época número 88, precisão de 26.96%
# Época número 89, precisão de 26.90%
# Época número 90, precisão de 26.85%
# Época número 91, precisão de 26.79%
# Época número 92, precisão de 26.75%
# Época número 93, precisão de 26.69%
# Época número 94, precisão de 26.65%
# Época número 95, precisão de 26.60%
# Época número 96, precisão de 26.52%
# Época número 97, precisão de 26.32%
# Época número 98, precisão de 26.00%
# Época número 99, precisão de 25.49%

# %%
accuracy(model, X_test, y_test)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.743814>
