# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2022-12-15 23:38:34.216338: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-15 23:38:34.438180: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-15 23:38:34.438202: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-15 23:38:34.469522: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-15 23:38:35.089156: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-15 23:38:35.089225: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-15 23:38:35.089233: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'PSK'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 8      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.5 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = 15      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy

# %%
#plot theoretical symbol error probability (SER) for this SNR
Pe = theoretical_error(Mod, M, SNR_dB, channel_type, epb=False)
print("Theoretical symbol error probability (SER) =", Pe*100, "% for SNR =", SNR_dB,"dB")
# Out:
# Theoretical symbol error probability (SER) = 3.4155801424019416 % for SNR = 15 dB

# %%
def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):
    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB)
    y = np.append(np.array([[]]), indices[:])
    x = np.stack([np.real(channel_output[:]),
                    np.imag(channel_output[:])], axis=1)
    
    if scaler is not None:
        x = scaler(x)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:train_size]
X_train = x_out[:train_size]

# Test
y_test = y_out[train_size:]
X_test = x_out[train_size:]

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]
n_hidden1 = 100
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.001
n_epochs = 30
batch_size = 150

y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(2,))

x = tf.keras.layers.Dense(n_hidden1, activation="relu", kernel_initializer="glorot_normal")(inputs)
x = tf.keras.layers.Dense(n_hidden2, activation="relu", kernel_initializer="glorot_normal")(x)
x = tf.keras.layers.Dense(n_hidden3, activation="relu", kernel_initializer="glorot_normal")(x)

output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)

modelK = tf.keras.Model(inputs=inputs, outputs=output)

modelK.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 2)]               0
#
#  dense_20 (Dense)            (None, 100)               300
#
#  dense_21 (Dense)            (None, 80)                8080
#
#  dense_22 (Dense)            (None, 50)                4050
#
#  dense_23 (Dense)            (None, 8)                 408
#
# =================================================================
# Total params: 12,838
# Trainable params: 12,838
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelK.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
             metrics=["accuracy"])

history = modelK.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, shuffle=True)

tests_score = modelK.evaluate(X_test, y_test)
print("Test loss:", tests_score[0])
print("Test accuracy:", tests_score[1])
print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}")
# Out:
# Epoch 1/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 1.6892 - accuracy: 0.6374
# Epoch 2/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.8103 - accuracy: 0.8870
# Epoch 3/30
# 3334/3334 [==============================] - 8s 3ms/step - loss: 0.4215 - accuracy: 0.9068
# Epoch 4/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.3213 - accuracy: 0.9075
# Epoch 5/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2872 - accuracy: 0.9076
# Epoch 6/30
# 3334/3334 [==============================] - 8s 3ms/step - loss: 0.2725 - accuracy: 0.9077
# Epoch 7/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2652 - accuracy: 0.9076
# Epoch 8/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2611 - accuracy: 0.9078
# Epoch 9/30
# 3334/3334 [==============================] - 8s 3ms/step - loss: 0.2586 - accuracy: 0.9077
# Epoch 10/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2569 - accuracy: 0.9078
# Epoch 11/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2557 - accuracy: 0.9078
# Epoch 12/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2547 - accuracy: 0.9078
# Epoch 13/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2538 - accuracy: 0.9077
# Epoch 14/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2530 - accuracy: 0.9078
# Epoch 15/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2523 - accuracy: 0.9079
# Epoch 16/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2517 - accuracy: 0.9078
# Epoch 17/30
# 3334/3334 [==============================] - 8s 2ms/step - loss: 0.2510 - accuracy: 0.9079
# Epoch 18/30
# 2838/3334 [========================>.....] - ETA: 1s - loss: 0.2508 - accuracy: 0.9077
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 5
#       1 modelK.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#       2              optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
#       3              metrics=["accuracy"])
# ----> 5 history = modelK.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, shuffle=True)
#       7 tests_score = modelK.evaluate(X_test, y_test)
#       8 print("Test loss:", tests_score[0])
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/keras/engine/training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2495, in Function.__call__(self, *args, **kwargs)
#    2492 """Calls a graph function specialized to the inputs."""
#    2493 with self._lock:
#    2494   (graph_function,
# -> 2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2738, in Function._maybe_define_function(self, args, kwargs)
#    2733 except TypeError as e:
#    2734   raise TypeError(
#    2735       "Arguments supplied to `defun`-generated functions must be hashable."
#    2736       ) from e
# -> 2738 graph_function = self._function_cache.lookup(func_cache_key, True)
#    2739 if graph_function is not None:
#    2740   return graph_function, filtered_flat_args
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:222, in FunctionCache.lookup(self, key, use_function_subtyping)
#     219 if not use_function_subtyping:
#     220   return self._primary.get(key, None)
# --> 222 dispatch_key = self._dispatch_table.dispatch(key)
#     223 if dispatch_key is not None:
#     224   return self._primary[dispatch_key]
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/type_dispatch.py:78, in TypeDispatchTable.dispatch(self, request)
#      76 """Returns the deepest subtype target if it exists in the table."""
#      77 # For known exact matches.
# ---> 78 if request in self._dispatch_table:
#      79   return request
#      81 # For known non-exact matches.
#      82 # (self._dispatch cache does not contain exact matches)
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_cache.py:175, in FunctionCacheKey.__hash__(self)
#     174 def __hash__(self) -> int:
# --> 175   return hash((self.call_context,
#     176                self.args_signature,
#     177                self.captures_signature))
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:207, in Tuple.__hash__(self)
#     206 def __hash__(self) -> int:
# --> 207   return hash(self.components)
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:207, in Tuple.__hash__(self)
#     206 def __hash__(self) -> int:
# --> 207   return hash(self.components)
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/core/function/trace_type/default_types.py:601, in Reference.__hash__(self)
#     600 def __hash__(self) -> int:
# --> 601   return hash((self.identifier, self.base))
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:482, in TypeSpec.__hash__(self)
#     481 def __hash__(self) -> int:
# --> 482   return hash(self.__get_cmp_key())
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:531, in TypeSpec.__get_cmp_key(self)
#     529 """Returns a hashable eq-comparable key for `self`."""
#     530 # TODO(b/133606651): Decide whether to cache this value.
# --> 531 return (type(self), self.__make_cmp_key(self._serialize()))
#
# File ~/anaconda3/envs/ML/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:535, in TypeSpec.__make_cmp_key(self, value)
#     533 def __make_cmp_key(self, value):
#     534   """Converts `value` to a hashable key."""
# --> 535   if isinstance(value, (int, float, bool, np.generic, dtypes.DType, TypeSpec,
#     536                         tensor_shape.TensorShape)):
#     537     return value
#     538   if isinstance(value, compat.bytes_or_text_types):
#
# File ~/anaconda3/envs/ML/lib/python3.10/abc.py:117, in ABCMeta.__instancecheck__(cls, instance)
#     111     """Register a virtual subclass of an ABC.
#     112
#     113     Returns the subclass, to allow usage as a class decorator.
#     114     """
#     115     return _abc_register(cls, subclass)
# --> 117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
#     119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
plot_confusion_matrix(modelK, X_test, y_test, M, nn=True)
plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
# Out:
# 2022-12-15 23:40:56.383550: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 200000000 exceeds 10% of free system memory.
# 2022-12-15 23:40:56.469606: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 200000000 exceeds 10% of free system memory.
# 2022-12-15 23:40:56.560605: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 200000000 exceeds 10% of free system memory.
# 2022-12-15 23:40:56.614779: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 160000000 exceeds 10% of free system memory.
# 2022-12-15 23:40:56.686350: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 160000000 exceeds 10% of free system memory.
# 8

# %%
Teo_SNRs = [theoretical_error(Mod, M, 12 + i, channel_type) for i in range(7)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, 12 + i, False, scaler.transform) for i in range(7)]

# %%
error_rate = (tf.constant(1.) - [modelK.evaluate(tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), 1)[1]
              for i in range(7)]) / (tf.math.log(float(M))/tf.math.log(2.))
# Out:
# 1540/1540 [==============================] - 2s 1ms/step - loss: 0.5273 - accuracy: 0.8266
# 1901/1901 [==============================] - 3s 1ms/step - loss: 0.4506 - accuracy: 0.8648
# 2356/2356 [==============================] - 3s 1ms/step - loss: 0.4329 - accuracy: 0.8727
# 2927/2927 [==============================] - 4s 1ms/step - loss: 0.3970 - accuracy: 0.9016
# 3647/3647 [==============================] - 5s 1ms/step - loss: 0.3745 - accuracy: 0.9172
# 4553/4553 [==============================] - 7s 1ms/step - loss: 0.3543 - accuracy: 0.9372
# 5693/5693 [==============================] - 8s 1ms/step - loss: 0.3409 - accuracy: 0.9478

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(12,19)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()
