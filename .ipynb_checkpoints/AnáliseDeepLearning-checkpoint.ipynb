# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2023-02-03 17:28:59.943656: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-03 17:28:59.943683: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-03 17:28:59.972362: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-02-03 17:29:00.672006: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:00.672087: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:00.672097: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'PSK'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 8      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.5 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = 15      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy

# %%
#plot theoretical symbol error probability (SER) for this SNR
Pe = theoretical_error(Mod, M, SNR_dB, channel_type, epb=False)
print("Theoretical symbol error probability (SER) =", Pe*100, "% for SNR =", SNR_dB,"dB")
# Out:
# Theoretical symbol error probability (SER) = 3.4155801424019416 % for SNR = 15 dB

# %%
def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):
    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB)
    y = np.append(np.array([[]]), indices[:])
    x = np.stack([np.real(channel_output[0][:]),
                    np.imag(channel_output[0][:])], axis=1)
    
    if scaler is not None:
        x = scaler(np.concatenate((x, np.array([channel_output[1]]).T), axis=1))
    else:
        x = np.concatenate((x, np.array([channel_output[1]]).T), axis=1)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
x_out
# Out:
# array([[-1.32861874, -1.47658003,  1.72003234],
#        [ 0.31289509, -0.2026149 ,  0.40577382],
#        [-0.02818798,  1.21817391,  1.40157219],
#        ...,
#        [ 0.14560816,  0.25498335,  0.23487796],
#        [ 0.12550442, -0.92550457,  0.92423579],
#        [-0.56765368, -0.3875729 ,  0.70106288]])

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:train_size]
X_train = x_out[:train_size]

# Test
y_test = y_out[train_size:]
X_test = x_out[train_size:]

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.01
n_epochs = 30
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)
# Out:
# 2023-02-03 17:29:07.106112: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106209: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106278: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106345: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106415: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106483: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106549: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106617: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-02-03 17:29:07.106629: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)


output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

modelK = tf.keras.Model(inputs=inputs, outputs=output)

modelK.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 150)               600
#
#  dense_1 (Dense)             (None, 80)                12080
#
#  dense_2 (Dense)             (None, 50)                4050
#
#  dense_3 (Dense)             (None, 8)                 408
#
# =================================================================
# Total params: 17,138
# Trainable params: 17,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelK.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
             metrics=["accuracy"])

history = modelK.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, shuffle=True)

tests_score = modelK.evaluate(X_test, y_test)
print("Test loss:", tests_score[0])
print("Test accuracy:", tests_score[1])
print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}")
# Out:
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3416 - accuracy: 0.8903
# Epoch 2/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2429 - accuracy: 0.9077
# Epoch 3/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2345 - accuracy: 0.9077
# Epoch 4/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2315 - accuracy: 0.9076
# Epoch 5/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2303 - accuracy: 0.9075
# Epoch 6/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2297 - accuracy: 0.9078
# Epoch 7/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2294 - accuracy: 0.9076
# Epoch 8/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2292 - accuracy: 0.9077
# Epoch 9/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2290 - accuracy: 0.9075
# Epoch 10/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2289 - accuracy: 0.9075
# Epoch 11/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2287 - accuracy: 0.9076
# Epoch 12/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2286 - accuracy: 0.9077
# Epoch 13/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2285 - accuracy: 0.9075
# Epoch 14/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2284 - accuracy: 0.9076
# Epoch 15/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2283 - accuracy: 0.9077
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2282 - accuracy: 0.9076
# Epoch 17/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2281 - accuracy: 0.9075
# Epoch 18/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2280 - accuracy: 0.9075
# Epoch 19/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2279 - accuracy: 0.9077
# Epoch 20/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2279 - accuracy: 0.9075
# Epoch 21/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2278 - accuracy: 0.9075
# Epoch 22/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2277 - accuracy: 0.9076
# Epoch 23/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2276 - accuracy: 0.9076
# Epoch 24/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2275 - accuracy: 0.9076
# Epoch 25/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2275 - accuracy: 0.9075
# Epoch 26/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2274 - accuracy: 0.9077
# Epoch 27/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2274 - accuracy: 0.9077
# Epoch 28/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2273 - accuracy: 0.9077
# Epoch 29/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2272 - accuracy: 0.9076
# Epoch 30/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2272 - accuracy: 0.9075
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.2267 - accuracy: 0.9081
# Test loss: 0.22669994831085205
# Test accuracy: 0.908128023147583
# Taxa de erro simbólica de 9.19%

# %%
plot_confusion_matrix(modelK, X_test, y_test, M, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### PSK | Rayleigh

# %%
Mod = "PSK"
channel_type = "rayleigh"
M = 8
init_scale = 8
interval = 7

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(interval)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(interval)]

# %%
error_rate = ([ser(modelK, tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(interval)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# 0.038921542

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### PSK | AWGN

# %%
Mod = 'PSK'
channel_type = 'awgn'
M = 8
init_scale = 8
interval = 7

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(interval)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(interval)]

# %%
error_rate = ([ser(modelK, tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(interval)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ## Modelo QAM

# %%
Mod = "QAM"
channel_type = "rayleigh"
M = 16

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:train_size]
X_train = x_out[:train_size]

# Test
y_test = y_out[train_size:]
X_test = x_out[train_size:]

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]
#n_hidden1 = 300
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.001
n_epochs = 30
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

#x = tf.keras.layers.Dense(n_hidden4, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

modelQ = tf.keras.Model(inputs=inputs, outputs=output)

modelQ.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3)]               0
#
#  dense_4 (Dense)             (None, 150)               600
#
#  dense_5 (Dense)             (None, 80)                12080
#
#  dense_6 (Dense)             (None, 50)                4050
#
#  dense_7 (Dense)             (None, 16)                816
#
# =================================================================
# Total params: 17,546
# Trainable params: 17,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelQ.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             optimizer=tf.keras.optimizers.Adam(),#experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
             metrics=["accuracy"])

history = modelQ.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, shuffle=True)

tests_score = modelQ.evaluate(X_test, y_test)
print("Test loss:", tests_score[0])
print("Test accuracy:", tests_score[1])
print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}")
# Out:
# Epoch 1/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6082 - accuracy: 0.7982
# Epoch 2/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4463 - accuracy: 0.8355
# Epoch 3/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4445 - accuracy: 0.8352
# Epoch 4/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4439 - accuracy: 0.8352
# Epoch 5/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4435 - accuracy: 0.8350
# Epoch 6/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4431 - accuracy: 0.8352
# Epoch 7/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4430 - accuracy: 0.8351
# Epoch 8/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4426 - accuracy: 0.8355
# Epoch 9/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4423 - accuracy: 0.8355
# Epoch 10/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4421 - accuracy: 0.8350
# Epoch 11/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4420 - accuracy: 0.8355
# Epoch 12/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4418 - accuracy: 0.8356
# Epoch 13/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4419 - accuracy: 0.8351
# Epoch 14/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4418 - accuracy: 0.8352
# Epoch 15/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4415 - accuracy: 0.8357
# Epoch 16/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4415 - accuracy: 0.8355
# Epoch 17/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4412 - accuracy: 0.8357
# Epoch 18/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4410 - accuracy: 0.8355
# Epoch 19/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4412 - accuracy: 0.8357
# Epoch 20/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4409 - accuracy: 0.8357
# Epoch 21/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4409 - accuracy: 0.8355
# Epoch 22/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4405 - accuracy: 0.8354
# Epoch 23/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4406 - accuracy: 0.8359
# Epoch 24/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4408 - accuracy: 0.8357
# Epoch 25/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4406 - accuracy: 0.8358
# Epoch 26/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4406 - accuracy: 0.8356
# Epoch 27/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4404 - accuracy: 0.8357
# Epoch 28/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4406 - accuracy: 0.8356
# Epoch 29/30
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4403 - accuracy: 0.8356
# Epoch 30/30
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4403 - accuracy: 0.8358
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.4440 - accuracy: 0.8344
# Test loss: 0.4439626932144165
# Test accuracy: 0.8343780040740967
# Taxa de erro simbólica de 16.56%

# %%
plot_confusion_matrix(modelQ, X_test, y_test, M, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | Rayleigh

# %%
Mod = 'QAM'
channel_type = 'rayleigh'
M = 16
init_scale = 8
interval = 7

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(interval)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(interval)]

# %%
error_rate = ([ser(modelQ, tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(interval)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# 0.04714688

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### QAM | AWGN

# %%
Mod = 'QAM'
channel_type = 'awgn'
M = 16
init_scale = 8
interval = 7

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(interval)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(interval)]

# %%
error_rate = ([ser(modelQ, tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(interval)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()
