# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2022-12-18 11:25:35.848810: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-18 11:25:36.943045: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-18 11:25:36.943085: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-18 11:25:37.099411: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-18 11:25:39.119121: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-18 11:25:39.119349: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-18 11:25:39.119376: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'PSK'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 8      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.5 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = 15      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy

# %%
#plot theoretical symbol error probability (SER) for this SNR
Pe = theoretical_error(Mod, M, SNR_dB, channel_type, epb=False)
print("Theoretical symbol error probability (SER) =", Pe*100, "% for SNR =", SNR_dB,"dB")
# Out:
# Theoretical symbol error probability (SER) = 3.4155801424019416 % for SNR = 15 dB

# %%
def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):
    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB)
    y = np.append(np.array([[]]), indices[:])
    x = np.stack([np.real(channel_output[:]),
                    np.imag(channel_output[:])], axis=1)
    
    if scaler is not None:
        x = scaler(x)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:train_size]
X_train = x_out[:train_size]

# Test
y_test = y_out[train_size:]
X_test = x_out[train_size:]

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.01
n_epochs = 30
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(2,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)


output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

modelK = tf.keras.Model(inputs=inputs, outputs=output)

modelK.summary()
# Out:
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 2)]               0
#
#  dense_44 (Dense)            (None, 150)               450
#
#  dense_45 (Dense)            (None, 80)                12080
#
#  dense_46 (Dense)            (None, 50)                4050
#
#  dense_47 (Dense)            (None, 8)                 408
#
# =================================================================
# Total params: 16,988
# Trainable params: 16,988
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelK.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
             metrics=["accuracy"])

history = modelK.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, shuffle=True)

tests_score = modelK.evaluate(X_test, y_test)
print("Test loss:", tests_score[0])
print("Test accuracy:", tests_score[1])
print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}")
# Out:
# Epoch 1/30
# 625/625 [==============================] - 6s 9ms/step - loss: 0.3627 - accuracy: 0.8915
# Epoch 2/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2564 - accuracy: 0.9084
# Epoch 3/30
# 625/625 [==============================] - 6s 9ms/step - loss: 0.2504 - accuracy: 0.9085
# Epoch 4/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2460 - accuracy: 0.9085
# Epoch 5/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2429 - accuracy: 0.9084
# Epoch 6/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2410 - accuracy: 0.9083
# Epoch 7/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2399 - accuracy: 0.9081
# Epoch 8/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2392 - accuracy: 0.9084
# Epoch 9/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2385 - accuracy: 0.9084
# Epoch 10/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2381 - accuracy: 0.9084
# Epoch 11/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2377 - accuracy: 0.9084
# Epoch 12/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2374 - accuracy: 0.9083
# Epoch 13/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2371 - accuracy: 0.9083
# Epoch 14/30
# 625/625 [==============================] - 6s 9ms/step - loss: 0.2369 - accuracy: 0.9083
# Epoch 15/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2367 - accuracy: 0.9084
# Epoch 16/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2366 - accuracy: 0.9083
# Epoch 17/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2365 - accuracy: 0.9082
# Epoch 18/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2363 - accuracy: 0.9083
# Epoch 19/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2364 - accuracy: 0.9083
# Epoch 20/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2363 - accuracy: 0.9082
# Epoch 21/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2363 - accuracy: 0.9083
# Epoch 22/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2362 - accuracy: 0.9081
# Epoch 23/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2362 - accuracy: 0.9081
# Epoch 24/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2361 - accuracy: 0.9082
# Epoch 25/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2362 - accuracy: 0.9083
# Epoch 26/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.2361 - accuracy: 0.9081
# Epoch 27/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2362 - accuracy: 0.9081
# Epoch 28/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2361 - accuracy: 0.9082
# Epoch 29/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2361 - accuracy: 0.9083
# Epoch 30/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.2362 - accuracy: 0.9082
# 15625/15625 [==============================] - 49s 3ms/step - loss: 0.2372 - accuracy: 0.9077
# Test loss: 0.23724199831485748
# Test accuracy: 0.9077439904212952
# Taxa de erro simbólica de 9.23%

# %%
plot_confusion_matrix(modelK, X_test, y_test, M, nn=True)
plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
# Out:
# 8

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### PSK | Rayleigh

# %%
Mod = "PSK"
channel_type = "rayleigh"
M = 8

# %%
Teo_SNRs = [theoretical_error(Mod, M, 12 + i, channel_type) for i in range(7)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, 12 + i, False, scaler.transform) for i in range(7)]

# %%
error_rate = (tf.constant(1.) - [modelK.evaluate(tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), 1)[1]
              for i in range(7)]) / (tf.math.log(float(M))/tf.math.log(2.))
# Out:
# 1540/1540 [==============================] - 5s 3ms/step - loss: 0.5380 - accuracy: 0.8247
# 1901/1901 [==============================] - 6s 3ms/step - loss: 0.3556 - accuracy: 0.8685
# 2356/2356 [==============================] - 8s 3ms/step - loss: 0.2850 - accuracy: 0.8926
# 2927/2927 [==============================] - 9s 3ms/step - loss: 0.2289 - accuracy: 0.9095
# 3647/3647 [==============================] - 11s 3ms/step - loss: 0.2031 - accuracy: 0.9202
# 4553/4553 [==============================] - 14s 3ms/step - loss: 0.1690 - accuracy: 0.9381
# 5693/5693 [==============================] - 17s 3ms/step - loss: 0.1445 - accuracy: 0.9519

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(12,19)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### PSK | AWGN

# %%
Mod = 'PSK'
channel_type = 'awgn'
M = 8

# %%
Teo_SNRs = [theoretical_error(Mod, M, 12 + i, channel_type) for i in range(7)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, 12 + i, False, scaler.transform) for i in range(7)]

# %%
error_rate = (tf.constant(1.) - [modelK.evaluate(tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), 1)[1]
              for i in range(7)]) / (tf.math.log(float(M))/tf.math.log(2.))
# Out:
# 3205/3205 [==============================] - 10s 3ms/step - loss: 0.0836 - accuracy: 0.9685
# 6397/6397 [==============================] - 20s 3ms/step - loss: 0.0439 - accuracy: 0.9831
# 14970/14970 [==============================] - 46s 3ms/step - loss: 0.0199 - accuracy: 0.9923
# 42745/42745 [==============================] - 131s 3ms/step - loss: 0.0091 - accuracy: 0.9973
# 156620/156620 [==============================] - 481s 3ms/step - loss: 0.0034 - accuracy: 0.9993
# 784749/784749 [==============================] - 2837s 4ms/step - loss: 0.0013 - accuracy: 0.9999
# 5825181/5825181 [==============================] - 12646s 2ms/step - loss: 5.6765e-04 - accuracy: 1.0000

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(12,19)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ## Modelo QAM

# %%
Mod = "QAM"
channel_type = "rayleigh"
M = 16

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:train_size]
X_train = x_out[:train_size]

# Test
y_test = y_out[train_size:]
X_test = x_out[train_size:]

scaler = StandardScaler()
scaler.fit(X_train)  # Don't cheat - fit only on training data
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
plot_symbols(X_train, y_train, M, symbs)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train)[1]
#n_hidden1 = 300
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.001
n_epochs = 30
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [-1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [-1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(2,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

#x = tf.keras.layers.Dense(n_hidden4, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

modelQ = tf.keras.Model(inputs=inputs, outputs=output)

modelQ.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 2)]               0
#
#  dense_45 (Dense)            (None, 150)               450
#
#  dense_46 (Dense)            (None, 80)                12080
#
#  dense_47 (Dense)            (None, 50)                4050
#
#  dense_48 (Dense)            (None, 16)                816
#
# =================================================================
# Total params: 17,396
# Trainable params: 17,396
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelQ.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             optimizer=tf.keras.optimizers.Adam(),#experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
             metrics=["accuracy"])

history = modelQ.fit(X_train, y_train, batch_size=batch_size, epochs=n_epochs, shuffle=True)

tests_score = modelQ.evaluate(X_test, y_test)
print("Test loss:", tests_score[0])
print("Test accuracy:", tests_score[1])
print(f"Taxa de erro simbólica de {(1 - tests_score[1]):.2%}")
# Out:
# Epoch 1/30
# 625/625 [==============================] - 5s 6ms/step - loss: 0.8510 - accuracy: 0.7044
# Epoch 2/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7298 - accuracy: 0.7298
# Epoch 3/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7257 - accuracy: 0.7303
# Epoch 4/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7247 - accuracy: 0.7304
# Epoch 5/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7236 - accuracy: 0.7304
# Epoch 6/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7235 - accuracy: 0.7306
# Epoch 7/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7229 - accuracy: 0.7304
# Epoch 8/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7229 - accuracy: 0.7309
# Epoch 9/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7224 - accuracy: 0.7307
# Epoch 10/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7229 - accuracy: 0.7307
# Epoch 11/30
# 625/625 [==============================] - 5s 9ms/step - loss: 0.7225 - accuracy: 0.7306
# Epoch 12/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.7222 - accuracy: 0.7307
# Epoch 13/30
# 625/625 [==============================] - 5s 8ms/step - loss: 0.7221 - accuracy: 0.7305
# Epoch 14/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7220 - accuracy: 0.7310
# Epoch 15/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7219 - accuracy: 0.7309
# Epoch 16/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7219 - accuracy: 0.7310
# Epoch 17/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7220 - accuracy: 0.7306
# Epoch 18/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7224 - accuracy: 0.7305
# Epoch 19/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7217 - accuracy: 0.7306
# Epoch 20/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7218 - accuracy: 0.7304
# Epoch 21/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7214 - accuracy: 0.7310
# Epoch 22/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7214 - accuracy: 0.7307
# Epoch 23/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7215 - accuracy: 0.7309
# Epoch 24/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7212 - accuracy: 0.7311
# Epoch 25/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.7213 - accuracy: 0.7313
# Epoch 26/30
# 625/625 [==============================] - 5s 7ms/step - loss: 0.7214 - accuracy: 0.7311
# Epoch 27/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7214 - accuracy: 0.7312
# Epoch 28/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7213 - accuracy: 0.7309
# Epoch 29/30
# 625/625 [==============================] - 4s 6ms/step - loss: 0.7213 - accuracy: 0.7309
# Epoch 30/30
# 625/625 [==============================] - 4s 7ms/step - loss: 0.7214 - accuracy: 0.7311
# 15625/15625 [==============================] - 33s 2ms/step - loss: 0.7242 - accuracy: 0.7300
# Test loss: 0.724192202091217
# Test accuracy: 0.729997992515564
# Taxa de erro simbólica de 27.00%

# %%
plot_confusion_matrix(modelQ, X_test, y_test, M, nn=True)
plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True)
plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True, plot_training=False)
# Out:
# 16
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 16

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | Rayleigh

# %%
Mod = 'QAM'
channel_type = 'rayleigh'
M = 16

# %%
Teo_SNRs = [theoretical_error(Mod, M, 12 + i, channel_type) for i in range(7)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, 12 + i, False, scaler.transform) for i in range(7)]

# %%
error_rate = (tf.constant(1.) - [modelQ.evaluate(tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), 1)[1]
              for i in range(7)]) / (tf.math.log(float(M))/tf.math.log(2.))
# Out:
# 944/944 [==============================] - 2s 2ms/step - loss: 1.1445 - accuracy: 0.6186
# 1163/1163 [==============================] - 2s 2ms/step - loss: 0.8395 - accuracy: 0.7059
# 1438/1438 [==============================] - 3s 2ms/step - loss: 0.8060 - accuracy: 0.6968
# 1785/1785 [==============================] - 4s 2ms/step - loss: 0.7710 - accuracy: 0.7176
# 2222/2222 [==============================] - 5s 2ms/step - loss: 0.6525 - accuracy: 0.7610
# 2772/2772 [==============================] - 6s 2ms/step - loss: 0.6056 - accuracy: 0.7727
# 3464/3464 [==============================] - 7s 2ms/step - loss: 0.5736 - accuracy: 0.7895

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(12,19)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("linear")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### QAM | AWGN

# %%
Mod = 'QAM'
channel_type = 'awgn'
M = 16

# %%
Teo_SNRs = [theoretical_error(Mod, M, 12 + i, channel_type) for i in range(7)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[i] * np.log2(M))), M, channel_type, Es, code_rate, 12 + i, False, scaler.transform) for i in range(7)]

# %%
error_rate = (tf.constant(1.) - [modelQ.evaluate(tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), 1)[1]
              for i in range(7)]) / (tf.math.log(float(M))/tf.math.log(2.))
# Out:
# 914/914 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.8118
# 1482/1482 [==============================] - 3s 2ms/step - loss: 0.4391 - accuracy: 0.8617
# 2691/2691 [==============================] - 5s 2ms/step - loss: 0.3485 - accuracy: 0.8911
# 5623/5623 [==============================] - 12s 2ms/step - loss: 0.2527 - accuracy: 0.9330
# 13982/13982 [==============================] - 29s 2ms/step - loss: 0.2158 - accuracy: 0.9476
# 43165/43165 [==============================] - 92s 2ms/step - loss: 0.1860 - accuracy: 0.9661
# 174629/174629 [==============================] - 366s 2ms/step - loss: 0.1648 - accuracy: 0.9791

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(12,19)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('Error per Bit')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Error rate')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()
