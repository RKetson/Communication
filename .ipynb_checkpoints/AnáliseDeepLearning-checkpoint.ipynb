# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2023-03-01 13:15:13.499622: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:13.499647: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-03-01 13:15:13.528764: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-03-01 13:15:14.250646: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:14.250729: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:14.250739: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'PSK'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 8      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.5 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = [15, 20, 25]      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy
faixa_snr = len(SNR_dB)

# %%
#plot theoretical symbol error probability (SER) for this SNR
Pe = theoretical_error(Mod, M, SNR_dB[0], channel_type, epb=False)
print("Theoretical symbol error probability (SER) =", Pe*100, "% for SNR =", SNR_dB,"dB")
# Out:
# Theoretical symbol error probability (SER) = 9.313001117891096 % for SNR = [15, 20, 25] dB

# %%
def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):

    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB[0])
    x = np.stack([np.real(channel_output[0][:]),
                    np.imag(channel_output[0][:])], axis=1)

    if scaler is not None:
        x = scaler(np.concatenate((x, np.array([channel_output[1]]).T), axis=1))
    else:
        x = np.concatenate((x, np.array([channel_output[1]]).T), axis=1)
    
    x = x.reshape(1,-1,3)
    
    for i in range(1, len(SNR_dB)):
        a, b, c = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB[i])
        
        d = np.stack([np.real(c[0][:]), np.imag(c[0][:])], axis=1)
        
        if scaler is not None:
            d = scaler(np.concatenate((d, np.array([c[1]]).T), axis=1))
        else:
            d = np.concatenate((d, np.array([c[1]]).T), axis=1)
        
        symbs = np.vstack((symbs, a))
        indices = np.vstack((indices, b))
        channel_output = np.vstack((channel_output, c))
        x = np.vstack((x, d.reshape(1,-1,3)))
    
    y = np.float_(indices)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
x_out
# Out:
# array([[[-0.66970781, -0.59175874,  0.81899262],
#         [-0.57549183, -0.51086013,  0.5606913 ],
#         [-0.030522  ,  0.55685063,  0.38873846],
#         ...,
#         [ 0.81606456,  0.74806573,  1.10945159],
#         [-0.53879996, -0.27859687,  0.56553268],
#         [-0.43119178,  0.38803911,  0.36432585]],
#
#        [[ 0.42361593,  0.25978347,  0.54638285],
#         [-0.46628473, -0.12808265,  0.57498629],
#         [ 0.01657102, -0.03109168,  0.11662207],
#         ...,
#         [ 0.49905399,  0.4461281 ,  0.62904755],
#         [ 1.05132901, -1.06918629,  1.62325816],
#         [-1.20963448, -0.09602166,  1.10901115]],
#
#        [[ 0.76165707, -0.72034223,  1.02431763],
#         [-0.26326045, -0.24763184,  0.38803345],
#         [ 1.54826154, -0.03766058,  1.54628415],
#         ...,
#         [-0.70816369, -0.00936431,  0.67471104],
#         [ 0.28099109, -0.3368964 ,  0.4011282 ],
#         [ 0.38421625,  0.33652893,  0.56332495]]])

# %%
y_out
# Out:
# array([[6., 6., 3., ..., 2., 6., 4.],
#        [2., 5., 6., ..., 2., 0., 5.],
#        [0., 6., 1., ..., 5., 0., 2.]])

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:,:train_size]
X_train = x_out[:,:train_size,:]

# Test
y_test = y_out[:,train_size:]
X_test = x_out[:,train_size:,:]

scaler = StandardScaler()
for i in range(faixa_snr):
    scaler.fit(X_train[i])  # Don't cheat - fit only on training data
    X_train[i] = scaler.transform(X_train[i])
    X_test[i] = scaler.transform(X_test[i])

# %%
for x, y, s in zip(X_train, y_train, symbs):
    plot_symbols(x, y, M, s)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train[0])[1]
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.01
n_epochs = 10
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [faixa_snr, -1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [faixa_snr, -1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)
# Out:
# 2023-03-01 13:15:21.017166: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017289: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017397: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017500: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017605: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017729: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017853: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017961: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-03-01 13:15:21.017976: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)


output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

# %%
for i in range(faixa_snr):
    model_PSK.append(tf.keras.Model(inputs=inputs, outputs=output))

    model_PSK[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                 metrics=["accuracy"])

    history = model_PSK[i].fit(X_train[i], y_train[i], batch_size=batch_size, epochs=n_epochs, shuffle=True)

    tests_score = model_PSK[i].evaluate(X_test[i], y_test[i])
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica para SNR = {SNR_dB[i]} de {(1 - tests_score[1]):.2%}\n")
# Out:
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3429 - accuracy: 0.8914
# Epoch 2/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2420 - accuracy: 0.9079
# Epoch 3/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2328 - accuracy: 0.9077
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2301 - accuracy: 0.9078
# Epoch 5/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2291 - accuracy: 0.9078
# Epoch 6/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2287 - accuracy: 0.9081
# Epoch 7/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2284 - accuracy: 0.9081
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2282 - accuracy: 0.9080
# Epoch 9/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2280 - accuracy: 0.9079
# Epoch 10/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2279 - accuracy: 0.9079
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.2283 - accuracy: 0.9082
#
# Test loss: 0.2282603681087494
# Test accuracy: 0.9081699848175049
# Taxa de erro simbólica para SNR = 15 de 9.18%
#
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0871 - accuracy: 0.9676
# Epoch 2/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0830 - accuracy: 0.9676
# Epoch 3/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0823 - accuracy: 0.9676
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0819 - accuracy: 0.9675
# Epoch 5/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0816 - accuracy: 0.9676
# Epoch 6/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0814 - accuracy: 0.9676
# Epoch 7/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0812 - accuracy: 0.9676
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0811 - accuracy: 0.9676
# Epoch 9/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0811 - accuracy: 0.9676
# Epoch 10/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0810 - accuracy: 0.9676
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.0801 - accuracy: 0.9683
#
# Test loss: 0.08009732514619827
# Test accuracy: 0.968313992023468
# Taxa de erro simbólica para SNR = 20 de 3.17%
#
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0296 - accuracy: 0.9895
# Epoch 2/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0275 - accuracy: 0.9896
# Epoch 3/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0273 - accuracy: 0.9895
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0272 - accuracy: 0.9895
# Epoch 5/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0271 - accuracy: 0.9895
# Epoch 6/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0270 - accuracy: 0.9895
# Epoch 7/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0269 - accuracy: 0.9895
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0269 - accuracy: 0.9895
# Epoch 9/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0268 - accuracy: 0.9895
# Epoch 10/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0268 - accuracy: 0.9896
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.0277 - accuracy: 0.9893
#
# Test loss: 0.027707839384675026
# Test accuracy: 0.9892979860305786
# Taxa de erro simbólica para SNR = 25 de 1.07%

# %%
for m, x, y in zip(model_PSK, X_test, y_test):
    plot_confusion_matrix(m, x, y, M, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### PSK | Rayleigh

# %%
Mod = "PSK"
channel_type = "rayleigh"
M = 8
init_scale = 2
interval = 50
passo = 4

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(200 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_PSK[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(3, 13), dtype=float32, numpy=
# array([[1.7847025e-01, 1.2729658e-01, 8.1422016e-02, 3.6449481e-02,
#         1.4191502e-02, 6.5045743e-03, 3.0623765e-03, 1.2285290e-03,
#         5.3354312e-04, 2.2888697e-04, 1.2095657e-04, 9.3038929e-05,
#         7.1751718e-05],
#        [1.7847025e-01, 1.2729658e-01, 8.1422016e-02, 3.6449481e-02,
#         1.4191502e-02, 6.5045743e-03, 3.0623765e-03, 1.2285290e-03,
#         5.3354312e-04, 2.2888697e-04, 1.2095657e-04, 9.3038929e-05,
#         7.1751718e-05],
#        [1.7847025e-01, 1.2729658e-01, 8.1422016e-02, 3.6449481e-02,
#         1.4191502e-02, 6.5045743e-03, 3.0623765e-03, 1.2285290e-03,
#         5.3354312e-04, 2.2888697e-04, 1.2095657e-04, 9.3038929e-05,
#         7.1751718e-05]], dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# -0.00096285704

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title('8-PSK - Rayleigh')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### PSK | AWGN

# %%
Mod = 'PSK'
channel_type = 'awgn'
interval = 17
init_scale = 2
passo = 2

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_PSK[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(3, 9), dtype=float32, numpy=
# array([[1.6584565e-01, 1.3281250e-01, 8.4967323e-02, 5.5168409e-02,
#         2.9010734e-02, 9.3603740e-03, 2.5384102e-03, 2.1282934e-04,
#         5.2645005e-06],
#        [1.6584565e-01, 1.3281250e-01, 8.4967323e-02, 5.5168409e-02,
#         2.9010734e-02, 9.3603740e-03, 2.5384102e-03, 2.1282934e-04,
#         5.2645005e-06],
#        [1.6584565e-01, 1.3281250e-01, 8.4967323e-02, 5.5168409e-02,
#         2.9010734e-02, 9.3603740e-03, 2.5384102e-03, 2.1282934e-04,
#         5.2645005e-06]], dtype=float32)>

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title('8-PSK - AWGN')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ## Modelo QAM

# %%
Mod = "QAM"
channel_type = "rayleigh"
M = 16

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:,:train_size]
X_train = x_out[:,:train_size,:]

# Test
y_test = y_out[:,train_size:]
X_test = x_out[:,train_size:,:]

scaler = StandardScaler()
for i in range(faixa_snr):
    scaler.fit(X_train[i])  # Don't cheat - fit only on training data
    X_train[i] = scaler.transform(X_train[i])
    X_test[i] = scaler.transform(X_test[i])

# %%
for x, y, s in zip(X_train, y_train, symbs):
    plot_symbols(x, y, M, s)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train[0])[1]
#n_hidden1 = 300
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.001
n_epochs = 10
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [faixa_snr, -1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [faixa_snr, -1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

#x = tf.keras.layers.Dense(n_hidden4, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)

# %%
model_QAM = []
for i in range(faixa_snr):
    model_QAM.append(tf.keras.Model(inputs=inputs, outputs=output))

    model_QAM[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                 metrics=["accuracy"])

    history = model_QAM[i].fit(X_train[i], y_train[i], batch_size=batch_size, epochs=n_epochs, shuffle=True)

    tests_score = model_QAM[i].evaluate(X_test[i], y_test[i])
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica para SNR = {SNR_dB[i]} de {(1 - tests_score[1]):.2%}\n")
# Out:
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 1.8947 - accuracy: 0.4463
# Epoch 2/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.9583 - accuracy: 0.7821
# Epoch 3/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6390 - accuracy: 0.8249
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.5505 - accuracy: 0.8298
# Epoch 5/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.5216 - accuracy: 0.8319
# Epoch 6/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.5080 - accuracy: 0.8331
# Epoch 7/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4992 - accuracy: 0.8339
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4923 - accuracy: 0.8344
# Epoch 9/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4861 - accuracy: 0.8349
# Epoch 10/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.4804 - accuracy: 0.8351
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.4811 - accuracy: 0.8343
#
# Test loss: 0.4811130166053772
# Test accuracy: 0.834276020526886
# Taxa de erro simbólica para SNR = 15 de 16.57%
#
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2267 - accuracy: 0.9394
# Epoch 2/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2050 - accuracy: 0.9393
# Epoch 3/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1949 - accuracy: 0.9392
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1894 - accuracy: 0.9392
# Epoch 5/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1860 - accuracy: 0.9394
# Epoch 6/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1838 - accuracy: 0.9394
# Epoch 7/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1821 - accuracy: 0.9395
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.1808 - accuracy: 0.9395
# Epoch 9/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1796 - accuracy: 0.9396
# Epoch 10/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.1787 - accuracy: 0.9396
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.1786 - accuracy: 0.9393
#
# Test loss: 0.1786314696073532
# Test accuracy: 0.9392859935760498
# Taxa de erro simbólica para SNR = 20 de 6.07%
#
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.0831 - accuracy: 0.9797
# Epoch 2/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0777 - accuracy: 0.9797
# Epoch 3/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0743 - accuracy: 0.9796
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0718 - accuracy: 0.9796
# Epoch 5/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0700 - accuracy: 0.9797
# Epoch 6/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0686 - accuracy: 0.9797
# Epoch 7/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0675 - accuracy: 0.9797
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0666 - accuracy: 0.9797
# Epoch 9/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0659 - accuracy: 0.9797
# Epoch 10/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.0653 - accuracy: 0.9798
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.0648 - accuracy: 0.9797
#
# Test loss: 0.0648261234164238
# Test accuracy: 0.9796980023384094
# Taxa de erro simbólica para SNR = 25 de 2.03%

# %%
[plot_confusion_matrix(m, X_test[1], y_test[1], M, nn=True) for m in model_QAM]
# Out:
# [None, None, None]

# %%
for m, x, y in zip(model_QAM, X_test, y_test):
    plot_confusion_matrix(m, x, y, M, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | Rayleigh

# %%
Mod = 'QAM'
channel_type = 'rayleigh'
M = 16
init_scale = 2
interval = 48
passo = 4

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(200 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(3, 12), dtype=float32, numpy=
# array([[1.6943128e-01, 1.4824562e-01, 9.6703298e-02, 4.9479168e-02,
#         2.0744681e-02, 8.1920903e-03, 4.0684235e-03, 1.5726197e-03,
#         7.2562997e-04, 3.2946485e-04, 1.8801527e-04, 1.5680639e-04],
#        [1.6943128e-01, 1.4824562e-01, 9.6703298e-02, 4.9479168e-02,
#         2.0744681e-02, 8.1920903e-03, 4.0684235e-03, 1.5726197e-03,
#         7.2562997e-04, 3.2946485e-04, 1.8801527e-04, 1.5680639e-04],
#        [1.6943128e-01, 1.4824562e-01, 9.6703298e-02, 4.9479168e-02,
#         2.0744681e-02, 8.1920903e-03, 4.0684235e-03, 1.5726197e-03,
#         7.2562997e-04, 3.2946485e-04, 1.8801527e-04, 1.5680639e-04]],
#       dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# -0.010385368

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title('16-QAM - Rayleigh')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### QAM | AWGN

# %%
Mod = 'QAM'
channel_type = 'awgn'
init_scale = 2
interval = 19
passo = 2

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, [init_scale + i], False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.reshape(tf.convert_to_tensor(amostras[i][0]), [-1,3]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(3, 10), dtype=float32, numpy=
# array([[1.55405402e-01, 1.34615391e-01, 1.15384616e-01, 1.02836877e-01,
#         6.05555549e-02, 2.98140049e-02, 1.06837610e-02, 2.43169791e-03,
#         3.34995915e-04, 1.64370540e-05],
#        [1.55405402e-01, 1.34615391e-01, 1.15384616e-01, 1.02836877e-01,
#         6.05555549e-02, 2.98140049e-02, 1.06837610e-02, 2.43169791e-03,
#         3.34995915e-04, 1.64370540e-05],
#        [1.55405402e-01, 1.34615391e-01, 1.15384616e-01, 1.02836877e-01,
#         6.05555549e-02, 2.98140049e-02, 1.06837610e-02, 2.43169791e-03,
#         3.34995915e-04, 1.64370540e-05]], dtype=float32)>

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
[ax.plot(x, y2,'s--', label=(f"Empirical Curve SNR={SNR_dB[i]}")) for i, y2 in enumerate(error_rate)]
ax.set_title('16-QAM - AWGN')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()
