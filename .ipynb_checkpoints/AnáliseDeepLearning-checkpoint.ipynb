# %% [markdown]
# # Treinamento de Rede Neural com Tensorflow para análise do sinal

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from libs.commpy_mod import SISOFlatChannel

from files_01_detection.const_mod import generate_symbols, Model
from files_01_detection.const_analyzer import plot_decision_boundary, theoretical_error, ser, plot_confusion_matrix, plot_symbols
 
# %matplotlib inline
# Out:
# 2023-02-28 23:19:20.311999: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-28 23:19:20.527828: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-28 23:19:20.527852: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-28 23:19:20.563170: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-02-28 23:19:21.264618: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 23:19:21.264698: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-02-28 23:19:21.264706: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Definição e transmissão do sinal pelo canal

# %%
Mod = 'PSK'
channel_type = 'rayleigh' # 'awgn' or 'crazy'
M            = 8      # PSK modulation
total_num_symbols  = 1000000    # Number of transmitted symbols to be used for training and test
train_fraction = 0.5 # Fraction of whole data to be used for training (the remaining is for testing)
SNR_dB       = [15, 20, 25]      # Signal to noise ratio in dB     
code_rate    = 1       # Rate of the used code
Es           = 1       # Average symbol energy
faixa_snr = len(SNR_dB)

# %%
#plot theoretical symbol error probability (SER) for this SNR
Pe = theoretical_error(Mod, M, SNR_dB[0], channel_type, epb=False)
print("Theoretical symbol error probability (SER) =", Pe*100, "% for SNR =", SNR_dB,"dB")
# Out:
# Theoretical symbol error probability (SER) = 9.313001117891096 % for SNR = [15, 20, 25] dB

# %%
def conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, symb=False, scaler=None):

    symbs, indices, channel_output = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB[0])
    x = np.stack([np.real(channel_output[0][:]),
                    np.imag(channel_output[0][:])], axis=1)

    if scaler is not None:
        x = scaler(np.concatenate((x, np.array([channel_output[1]]).T), axis=1))
    else:
        x = np.concatenate((x, np.array([channel_output[1]]).T), axis=1)
    
    x = x.reshape(1,-1,3)
    
    for i in range(1, len(SNR_dB)):
        a, b, c = Model(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB[i])
        
        d = np.stack([np.real(c[0][:]), np.imag(c[0][:])], axis=1)
        
        if scaler is not None:
            d = scaler(np.concatenate((d, np.array([c[1]]).T), axis=1))
        else:
            d = np.concatenate((d, np.array([c[1]]).T), axis=1)
        
        symbs = np.vstack((symbs, a))
        indices = np.vstack((indices, b))
        channel_output = np.vstack((channel_output, c))
        x = np.vstack((x, d.reshape(1,-1,3)))
    
    y = np.float_(indices)
        
    if symb:
        return x, y, symbs
    else:
        return x, y

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
x_out
# Out:
# array([[[ 1.40386338,  0.07365254,  1.44706418],
#         [-0.29957692,  0.50830675,  0.54404368],
#         [ 0.85667085,  0.76765359,  1.27867616],
#         ...,
#         [-1.1685675 ,  1.0231406 ,  1.60330594],
#         [-0.01947451,  0.28029869,  0.2518406 ],
#         [-0.48540707, -0.15294107,  0.47289693]],
#
#        [[ 0.69979404, -0.68089866,  1.01879853],
#         [-0.59263028, -0.51358908,  0.73847107],
#         [ 1.39845429, -1.39382225,  1.94789483],
#         ...,
#         [ 0.7842068 , -0.00205808,  0.73633538],
#         [ 0.0230533 ,  1.41406506,  1.50657812],
#         [ 0.70975302,  0.49957007,  0.8647335 ]],
#
#        [[-0.53729571,  0.57929236,  0.86065749],
#         [-0.38747596, -0.30888039,  0.49939056],
#         [-0.26081489, -0.2303993 ,  0.33782871],
#         ...,
#         [ 0.57535956, -0.64656262,  0.86791065],
#         [-0.62707911,  0.57930625,  0.86351037],
#         [ 0.44541023,  0.44160271,  0.66123221]]])

# %%
y_out
# Out:
# array([[1., 4., 2., ..., 4., 2., 5.],
#        [0., 6., 0., ..., 1., 3., 2.],
#        [4., 6., 6., ..., 0., 4., 2.]])

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:,:train_size]
X_train = x_out[:,:train_size,:]

# Test
y_test = y_out[:,train_size:]
X_test = x_out[:,train_size:,:]

scaler = StandardScaler()
for i in range(faixa_snr):
    scaler.fit(X_train[i])  # Don't cheat - fit only on training data
    X_train[i] = scaler.transform(X_train[i])
    X_test[i] = scaler.transform(X_test[i])

# %%
for x, y, s in zip(X_train, y_train, symbs):
    plot_symbols(x, y, M, s)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train[0])[1]
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.01
n_epochs = 10
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [faixa_snr, -1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [faixa_snr, -1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)
# Out:
# 2023-02-28 23:45:14.755046: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 36000000 exceeds 10% of free system memory.
# 2023-02-28 23:45:14.877789: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 36000000 exceeds 10% of free system memory.

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)


output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 150)               600
#
#  dense_1 (Dense)             (None, 80)                12080
#
#  dense_2 (Dense)             (None, 50)                4050
#
#  dense_3 (Dense)             (None, 8)                 408
#
# =================================================================
# Total params: 17,138
# Trainable params: 17,138
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_PSK = []
for i in range(faixa_snr):
    model_PSK.append(tf.keras.Model(inputs=inputs, outputs=output))

    model_PSK[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                 metrics=["accuracy"])

    history = model_PSK[i].fit(X_train[i], y_train[i], batch_size=batch_size, epochs=n_epochs, shuffle=True)

    tests_score = model_PSK[i].evaluate(X_test[i], y_test[i])
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica para SNR = {SNR_dB[i]} de {(1 - tests_score[1]):.2%}\n")
# Out:
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.3418 - accuracy: 0.8950
# Epoch 2/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2429 - accuracy: 0.9075
# Epoch 3/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2338 - accuracy: 0.9077
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2310 - accuracy: 0.9074
# Epoch 5/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2301 - accuracy: 0.9076
# Epoch 6/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2296 - accuracy: 0.9076
# Epoch 7/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2294 - accuracy: 0.9076
# Epoch 8/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.2292 - accuracy: 0.9077
# Epoch 9/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2291 - accuracy: 0.9076
# Epoch 10/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.2290 - accuracy: 0.9076
# 15625/15625 [==============================] - 16s 999us/step - loss: 0.2281 - accuracy: 0.9077
# Test loss: 0.228064626455307
# Test accuracy: 0.9077240228652954
# Taxa de erro simbólica de 9.23%

# %%
for m, x, y in zip(model_PSK, X_test, y_test):
    plot_confusion_matrix(m, X_test, y_test, M, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelK, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### PSK | Rayleigh

# %%
Mod = "PSK"
channel_type = "rayleigh"
M = 8
init_scale = 2
interval = 50
passo = 4

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(200 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_PSK[j], tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(13,), dtype=float32, numpy=
# array([0.19357884, 0.12729658, 0.07454129, 0.03531634, 0.01536021,
#        0.00848725, 0.00330229, 0.00143234, 0.00086814, 0.00055239,
#        0.00047485, 0.00042646, 0.0004172 ], dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# -1.049646e-05

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('8-PSK - Rayleigh')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### PSK | AWGN

# %%
Mod = 'PSK'
channel_type = 'awgn'
interval = 17
init_scale = 2
passo = 2

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_PSK[j], tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(9,), dtype=float32, numpy=
# array([1.4942528e-01, 1.3020833e-01, 8.4033616e-02, 5.8652729e-02,
#        3.3652451e-02, 9.4643785e-03, 2.2266756e-03, 2.0005960e-04,
#        5.5506148e-06], dtype=float32)>

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('8-PSK - AWGN')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ## Modelo QAM

# %%
Mod = "QAM"
channel_type = "rayleigh"
M = 16

# %%
x_out, y_out, symbs = conjunto(Mod, total_num_symbols, M, channel_type, Es, code_rate, SNR_dB, True)

# %%
# Generate dataset
# Train
train_size = int(train_fraction*total_num_symbols) #data used for training
y_train = y_out[:,:train_size]
X_train = x_out[:,:train_size,:]

# Test
y_test = y_out[:,train_size:]
X_test = x_out[:,train_size:,:]

scaler = StandardScaler()
for i in range(faixa_snr):
    scaler.fit(X_train[i])  # Don't cheat - fit only on training data
    X_train[i] = scaler.transform(X_train[i])
    X_test[i] = scaler.transform(X_test[i])

# %%
for x, y, s in zip(X_train, y_train, symbs):
    plot_symbols(x, y, M, s)

# %% [markdown]
# ## Criação e treinamento da Rede Neural

# %%
n_inputs = np.shape(X_train[0])[1]
#n_hidden1 = 300
n_hidden1 = 150
n_hidden2 = 80
n_hidden3 = 50

n_outputs = M
learning_rate = 0.001
n_epochs = 10
batch_size = 800

y_train = tf.reshape(tf.convert_to_tensor(y_train), [faixa_snr, -1, 1])
y_test = tf.reshape(tf.convert_to_tensor(y_test), [faixa_snr, -1, 1])
X_test = tf.convert_to_tensor(X_test)
X_train = tf.convert_to_tensor(X_train)

# %% [markdown]
# ### Usando API Keras

# %%
inputs = tf.keras.Input(shape=(3,))

x = tf.keras.layers.Dense(n_hidden1, activation="elu", kernel_initializer="glorot_normal")(inputs)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden2, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

x = tf.keras.layers.Dense(n_hidden3, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

#x = tf.keras.layers.Dense(n_hidden4, activation="elu", kernel_initializer="glorot_normal")(x)
#x = tf.keras.layers.BatchNormalization(momentum=0.99)(x)
#x = tf.keras.layers.Activation("elu")(x)

output = tf.keras.layers.Dense(n_outputs, kernel_initializer="glorot_normal")(x)
#output = tf.keras.layers.BatchNormalization(momentum=0.99)(output)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3)]               0
#
#  dense_4 (Dense)             (None, 150)               600
#
#  dense_5 (Dense)             (None, 80)                12080
#
#  dense_6 (Dense)             (None, 50)                4050
#
#  dense_7 (Dense)             (None, 16)                816
#
# =================================================================
# Total params: 17,546
# Trainable params: 17,546
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_QAM = []
for i in range(faixa_snr):
    model_QAM.append(tf.keras.Model(inputs=inputs, outputs=output))

    model_QAM[i].compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=learning_rate, momentum=0.9, nesterov=True),
                 metrics=["accuracy"])

    history = model_QAM[i].fit(X_train[i], y_train[i], batch_size=batch_size, epochs=n_epochs, shuffle=True)

    tests_score = model_QAM[i].evaluate(X_test[i], y_test[i])
    print("\nTest loss:", tests_score[0])
    print("Test accuracy:", tests_score[1])
    print(f"Taxa de erro simbólica para SNR = {SNR_dB[i]} de {(1 - tests_score[1]):.2%}\n")
# Out:
# Epoch 1/10
# 625/625 [==============================] - 3s 4ms/step - loss: 0.6135 - accuracy: 0.7954
# Epoch 2/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4500 - accuracy: 0.8340
# Epoch 3/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4483 - accuracy: 0.8344
# Epoch 4/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4475 - accuracy: 0.8344
# Epoch 5/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4470 - accuracy: 0.8341
# Epoch 6/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4468 - accuracy: 0.8344
# Epoch 7/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4462 - accuracy: 0.8342
# Epoch 8/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4459 - accuracy: 0.8343
# Epoch 9/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4457 - accuracy: 0.8347
# Epoch 10/10
# 625/625 [==============================] - 2s 4ms/step - loss: 0.4454 - accuracy: 0.8345
# 15625/15625 [==============================] - 16s 1ms/step - loss: 0.4394 - accuracy: 0.8369
# Test loss: 0.4394042491912842
# Test accuracy: 0.8369460105895996
# Taxa de erro simbólica de 16.31%

# %%
for m, x, y in zip(model_QAM, X_test, y_test):
    plot_confusion_matrix(m, x, y, M, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True)
#plot_decision_boundary(modelQ, X_train, y_train, legend=True, nn=True, plot_training=False)

# %% [markdown]
# ## Avaliação do modelo em diferentes faixas de relação sinal/ruído

# %% [markdown]
# ### QAM | Rayleigh

# %%
Mod = 'QAM'
channel_type = 'rayleigh'
M = 16
init_scale = 2
interval = 48
passo = 4

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(200 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(12,), dtype=float32, numpy=
# array([0.17772512, 0.1254386 , 0.08681319, 0.05295139, 0.0231383 ,
#        0.01022599, 0.00543227, 0.0034244 , 0.00258622, 0.00238936,
#        0.00235196, 0.00226027], dtype=float32)>

# %%
np.mean(error_rate - Teo_SNRs)
# Out:
# -0.0108103715

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('16-QAM - Rayleigh')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()

# %% [markdown]
# ### QAM | AWGN

# %%
Mod = 'QAM'
channel_type = 'awgn'
init_scale = 2
interval = 19
passo = 2

# %%
Teo_SNRs = [theoretical_error(Mod, M, init_scale + i, channel_type) for i in range(0, interval, passo)]

# %%
amostras = [conjunto(Mod, int(100 / (Teo_SNRs[int(i / passo)] * np.log2(M))), M, channel_type, Es, code_rate, init_scale + i, False, scaler.transform) for i in range(0, interval, passo)]

# %%
error_rate = ([[ser(model_QAM[j], tf.convert_to_tensor(amostras[i][0]),
                              tf.reshape(tf.convert_to_tensor(amostras[i][1]), [-1, 1]), nn=True)
              for i in range(len(amostras))] for j in range(faixa_snr)]) / (tf.math.log(float(M))/tf.math.log(2.))

# %%
error_rate
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([1.7905405e-01, 1.6272189e-01, 1.2379808e-01, 8.8652484e-02,
#        5.8888890e-02, 2.7352298e-02, 9.9405423e-03, 1.8416536e-03,
#        1.7465599e-04, 4.9659648e-06], dtype=float32)>

# %%
import matplotlib.ticker as tick

y1 = Teo_SNRs
x = range(init_scale, init_scale + interval, passo)
y2 = error_rate

fig, ax = plt.subplots(1,1)

ax.plot(x, y1, 'go-', label='Theoretical Curve', linewidth=2)
ax.plot(x, y2, 'rs--', label='Empirical Curve')
ax.set_title('16-QAM - AWGN')
ax.set_xlabel('SNR_dB')
ax.set_ylabel('Taxa de erro por bit')

def y_fmt(x, y):
    return '{:2.1e}'.format(x)

ax.set_yscale("log")
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
#plt.plot(x2, y2, 'rs--',  label='line 2')

plt.legend()
plt.show()
